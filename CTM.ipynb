# %% [markdown]
# <a href="https://colab.research.google.com/github/fatinirq/Content-Topic-Modeling/blob/main/CTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torchtext==0.10.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchtext==0.10.0
#   Downloading torchtext-0.10.0-cp37-cp37m-manylinux1_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 8.2 MB/s
# Collecting torch==1.9.0
#   Downloading torch-1.9.0-cp37-cp37m-manylinux1_x86_64.whl (831.4 MB)
#      |████████████████████████████████| 831.4 MB 2.5 kB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchtext==0.10.0) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext==0.10.0) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext==0.10.0) (4.64.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.9.0->torchtext==0.10.0) (4.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.10.0) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.10.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.10.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.10.0) (3.0.4)
# Installing collected packages: torch, torchtext
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.13.1
#     Uninstalling torchtext-0.13.1:
#       Successfully uninstalled torchtext-0.13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.13.1+cu113 requires torch==1.12.1, but you have torch 1.9.0 which is incompatible.
# torchaudio 0.12.1+cu113 requires torch==1.12.1, but you have torch 1.9.0 which is incompatible.
# Successfully installed torch-1.9.0 torchtext-0.10.0

# %%
! pip install  tomotopy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tomotopy
#   Downloading tomotopy-0.12.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (16.5 MB)
#      |████████████████████████████████| 16.5 MB 7.2 MB/s
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tomotopy) (1.21.6)
# Installing collected packages: tomotopy
# Successfully installed tomotopy-0.12.3

# %%
import json
import spacy
import pandas as pd
from torchtext.legacy import data
from torchtext.legacy.data import TabularDataset
from sklearn.model_selection import train_test_split
#from updatedRNN_model import RNN
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-b8be71512e55> in <module>
#       2 import spacy
#       3 import pandas as pd
# ----> 4 from torchtext.legacy import data
#       5 from torchtext.legacy.data import TabularDataset
#       6 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'torchtext.legacy'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
data = pd.read_csv('/content/drive/MyDrive/SpoilerData/LDA_CData.csv')
#data = [json.loads(line) for line in open('/content/drive/MyDrive/SpoilerData/CData.json', 'r')]
df=pd.DataFrame(data)

# %%
data = [json.loads(line) for line in open('/content/drive/MyDrive/SpoilerData/CData.json', 'r')]
df_review=pd.DataFrame(data)

# %%
del data
#sample = df.sample(frac=0.05)
#print(sample)

# %%
df_review.head()
# Out:
#                                     review_sentences  \
# 0  also high energy cosmic ray entering atmospher...
# 1  avail free december http www audible com mt el...
# 2  cheat system live choice learn daniela say lif...
# 3  http www npr org recommended reading understan...
# 4  surfer love end freya finding meaning surfing ...
#
#                             user_id   timestamp  rating  has_spoiler  \
# 0  8842281e1d1347389f2ab93d60773d4d  2017-08-30       5         True
# 1  8842281e1d1347389f2ab93d60773d4d  2017-03-22       3        False
# 2  8842281e1d1347389f2ab93d60773d4d  2017-03-20       3         True
# 3  8842281e1d1347389f2ab93d60773d4d  2016-11-09       0        False
# 4  8842281e1d1347389f2ab93d60773d4d  2016-04-25       4         True
#
#     book_id                         review_id
# 0  18245960  dfdbb7b0eb5a7e4c26d59a937e2e5feb
# 1     16981  a5d2c3628987712d0e05c4f90798eb67
# 2  28684704  2ede853b14dc4583f96cf5d120af636f
# 3  27161156  ced5675e55cd9d38a524743f5c40996e
# 4  25884323  332732725863131279a8e345b63ac33e

# %%
df['spoiled'].value_counts()
# Out:
# 0    17102931
# 1      569724
# Name: spoiled, dtype: int64

# %%
df2=df[df['spoiled']==1]

# %%
df2.head()
# Out:
#                                       review_sentence  spoiled  \
# 7   ['though', 'got', 'folding', 'proton', 'dimens...        1
# 8   ['would', 'happen', 'seti', 'station', 'receiv...        1
# 9   ['part', 'book', 'bit', 'dark', 'would', 'like...        1
# 10  ['like', 'book', 'unveiled', 'trisolaran', 'cu...        1
# 11  ['smart', 'way', 'build', 'empathy', 'also', '...        1
#
#                            review_id
# 7   dfdbb7b0eb5a7e4c26d59a937e2e5feb
# 8   dfdbb7b0eb5a7e4c26d59a937e2e5feb
# 9   dfdbb7b0eb5a7e4c26d59a937e2e5feb
# 10  dfdbb7b0eb5a7e4c26d59a937e2e5feb
# 11  dfdbb7b0eb5a7e4c26d59a937e2e5feb

# %%
# coding:utf-8

# 2.0  Use jieba Carry out word segmentation , Completely abandon inefficient NLPIR, use TextRank Algorithm assignment weight ( Actually measured textrank better )
# 2.1  use gensim To make tfidf
# 2.2 sklearn do tfidf and kmeans
# 2.3  take kmeans Change to BIRCH, Using tradition tfidf

import logging
import time
import os
import jieba
import glob
import random
import copy
import chardet
import gensim
from gensim import corpora,similarities, models
from pprint import pprint
import jieba.analyse
from sklearn import feature_extraction
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
import os
from sklearn.decomposition import PCA

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : 66e3805b8cabe977f40c05259cc3fcf7ead5687d
# python           : 3.7.13.final.0
# python-bits      : 64
# OS               : Linux
# OS-release       : 5.10.133+
# Version          : #1 SMP Fri Aug 26 08:44:51 UTC 2022
# machine          : x86_64
# processor        : x86_64
# byteorder        : little
# LC_ALL           : None
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 1.3.5
# numpy            : 1.21.6
# pytz             : 2022.2.1
# dateutil         : 2.8.2
# pip              : 21.1.3
# setuptools       : 57.4.0
# Cython           : 0.29.32
# pytest           : 3.6.4
# hypothesis       : None
# sphinx           : 1.8.6
# blosc            : None
# feather          : 0.4.1
# xlsxwriter       : None
# lxml.etree       : 4.9.1
# html5lib         : 1.0.1
# pymysql          : None
# psycopg2         : 2.9.3 (dt dec pq3 ext lo64)
# jinja2           : 2.11.3
# IPython          : 7.9.0
# pandas_datareader: 0.9.0
# bs4              : 4.6.3
# bottleneck       : None
# fsspec           : 2022.8.2
# fastparquet      : None
# gcsfs            : None
# matplotlib       : 3.2.2
# numexpr          : 2.8.3
# odfpy            : None
# openpyxl         : 3.0.10
# pandas_gbq       : 0.13.3
# pyarrow          : 6.0.1
# pyxlsb           : None
# s3fs             : None
# scipy            : 1.7.3
# sqlalchemy       : 1.4.41
# tables           : 3.7.0
# tabulate         : 0.8.10
# xarray           : 0.20.2
# xlrd             : 1.1.0
# xlwt             : 1.3.0
# numba            : 0.56.2

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
import nltk
np.random.seed(2018)
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %% [markdown]
# Applying code of this report [link text](https://towardsdatascience.com/topic-modeling-and-latent-dirichlet-allocation-in-python-9bf156893c24)

# %%
def lemmatize_stemming(text):
    stemmer = PorterStemmer()
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))
def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
           result.append(token)

    return result

# %%
df2['index'] = df2.index
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.head()
# Out:
#                                       review_sentence  spoiled  \
# 7   ['though', 'got', 'folding', 'proton', 'dimens...        1
# 8   ['would', 'happen', 'seti', 'station', 'receiv...        1
# 9   ['part', 'book', 'bit', 'dark', 'would', 'like...        1
# 10  ['like', 'book', 'unveiled', 'trisolaran', 'cu...        1
# 11  ['smart', 'way', 'build', 'empathy', 'also', '...        1
#
#                            review_id  index
# 7   dfdbb7b0eb5a7e4c26d59a937e2e5feb      7
# 8   dfdbb7b0eb5a7e4c26d59a937e2e5feb      8
# 9   dfdbb7b0eb5a7e4c26d59a937e2e5feb      9
# 10  dfdbb7b0eb5a7e4c26d59a937e2e5feb     10
# 11  dfdbb7b0eb5a7e4c26d59a937e2e5feb     11

# %%
my_string = "blah, lots  ,  of ,  spaces, here "
result = [x.strip() for x in my_string.split()]
# result is ["blah", "lots", "of", "spaces", "here"]
print (result)
# Out:
# ['blah,', 'lots', ',', 'of', ',', 'spaces,', 'here']

# %%
words = ["How","are","you","doing","?"]
sentence = ' '.join(words)
print(sentence)
# Out:
# How are you doing ?

# %%
doc_sample = df2[df2['index'] == 11].values[0][0]
print('original document: ')
words = []
for word in doc_sample.split(' '):
    words.append(word)
print(words)
print('\n\n tokenized and lemmatized document: ')
print(preprocess(doc_sample))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-25f5cf76e8be> in <module>
# ----> 1 doc_sample = df2[df2['index'] == 11].values[0][0]
#       2 print('original document: ')
#       3 words = []
#       4 for word in doc_sample.split(' '):
#       5     words.append(word)
#
# NameError: name 'df2' is not defined

# %%
processed_docs= df2['review_sentence'].map(preprocess)
processed_docs[:10]
# Out:
# 7     [folding, proton, dimension, think, making, st...
# 8     [happen, seti, station, received, message, per...
# 9     [book, dark, like, think, human, reaction, dis...
# 10    [like, book, unveiled, trisolaran, culture, game]
# 11    [smart, build, empathy, understand, gone, cent...
# 12     [know, body, problem, unsolvable, math, problem]
# 13                            [game, maybe, come, book]
# 14                                       [loved, quote]
# 15    [long, history, scientific, progress, proton, ...
# 16                                  [neutron, electron]
# Name: review_sentence, dtype: object

# %%
processed_docs.head()
# Out:
# 7     [folding, proton, dimension, think, making, st...
# 8     [happen, seti, station, received, message, per...
# 9     [book, dark, like, think, human, reaction, dis...
# 10    [like, book, unveiled, trisolaran, culture, game]
# 11    [smart, build, empathy, understand, gone, cent...
# Name: review_sentence, dtype: object

# %%
print(processed_docs[7])
# Out:
# ['folding', 'proton', 'dimension', 'think', 'making', 'stuff', 'interesting', 'think']

# %%
import gc
gc.enable()

# %%
print(df2['review_sentence'][7])
# Out:
# ['though', 'got', 'folding', 'proton', 'dimension', 'think', 'making', 'stuff', 'interesting', 'think', 'though']

# %%
import numpy as np
from nltk.tokenize import  word_tokenize
import nltk
import string
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
corpus=[]
for review in df2['review_sentence']:
  if len(review)>3:
    x = [i.lower() for  i in word_tokenize(review.translate(str.maketrans('', '', string.punctuation))) if i.isalpha()]
    corpus.append(' '.join(x))
print(corpus)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print (len(corpus))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-eff1eb72028c> in <module>
# ----> 1 print (len(corpus))
#
# NameError: name 'corpus' is not defined

# %%
from gensim.models import Word2Vec, FastText
import pandas as pd
import re

from sklearn.decomposition import PCA

from matplotlib import pyplot as plt
import plotly.graph_objects as go

import numpy as np

import warnings
warnings.filterwarnings('ignore')

#df = pd.read_csv('emails.csv')
# Out:
# 561860

# %%
lst=list(df2['review_sentence'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3db2748468d6> in <module>
# ----> 1 lst=list(df2['review_sentence'])
#
# NameError: name 'df2' is not defined

# %%
sentences = [['i', 'like', 'apple', 'pie', 'for', 'dessert'],
           ['i', 'dont', 'drive', 'fast', 'cars'],
           ['data', 'science', 'is', 'fun'],
           ['chocolate', 'is', 'my', 'favorite'],
           ['my', 'favorite', 'movie', 'is', 'predator']]
w2v = Word2Vec(processed_docs, min_count=1, size = 5)

print(w2v)
# Out:
# WARNING:gensim.models.base_any2vec:consider setting layer size to a multiple of 4 for greater performance
# Word2Vec(vocab=71826, size=5, alpha=0.025)

# %%
df2.head()
# Out:
#                                       review_sentence  spoiled  \
# 7   ['though', 'got', 'folding', 'proton', 'dimens...        1
# 8   ['would', 'happen', 'seti', 'station', 'receiv...        1
# 9   ['part', 'book', 'bit', 'dark', 'would', 'like...        1
# 10  ['like', 'book', 'unveiled', 'trisolaran', 'cu...        1
# 11  ['smart', 'way', 'build', 'empathy', 'also', '...        1
#
#                            review_id  index
# 7   dfdbb7b0eb5a7e4c26d59a937e2e5feb      7
# 8   dfdbb7b0eb5a7e4c26d59a937e2e5feb      8
# 9   dfdbb7b0eb5a7e4c26d59a937e2e5feb      9
# 10  dfdbb7b0eb5a7e4c26d59a937e2e5feb     10
# 11  dfdbb7b0eb5a7e4c26d59a937e2e5feb     11

# %%
print(w2v['unveiled'])
words = list(w2v.wv.vocab)

print(words)

#or show the dictionary of vocab words
w2v.wv.vocab
# Out:
# [ 0.23884611 -0.04884772 -0.1242032  -0.9315867   0.16349317]
# ['folding', 'proton', 'dimension', 'think', 'making', 'stuff', 'interesting', 'happen', 'seti', 'station', 'received', 'message', 'person', 'monitoring', 'answering', 'signal', 'disillusioned', 'book', 'dark', 'like', 'human', 'reaction', 'discovering', 'alien', 'civilization', 'hostile', 'enders', 'game', 'band', 'unveiled', 'trisolaran', 'culture', 'smart', 'build', 'empathy', 'understand', 'gone', 'century', 'know', 'body', 'problem', 'unsolvable', 'math', 'maybe', 'come', 'loved', 'quote', 'long', 'history', 'scientific', 'progress', 'smashed', 'apart', 'accelerator', 'physicist', 'neutron', 'electron', 'probably', 'fewer', 'million', 'collision', 'intelligence', 'microcosmos', 'fact', 'nature', 'destruction', 'universe', 'happening', 'second', 'example', 'decay', 'high', 'energy', 'cosmic', 'entering', 'atmosphere', 'destroy', 'thousand', 'miniature', 'discussed', 'spoiler', 'choice', 'regret', 'chasing', 'girl', 'dream', 'focus', 'career', 'jason', 'clearly', 'author', 'trying', 'tell', 'optimize', 'happiness', 'rate', 'physic', 'teacher', 'community', 'college', 'mean', 'happy', 'life', 'snarky', 'certainly', 'meaning', 'thought', 'little', 'shallow', 'character', 'fairly', 'daniela', 'perfect', 'wife', 'ryan', 'antithesis', 'amanda', 'loyal', 'traveling', 'companion', 'plus', 'weak', 'science', 'star', 'read', 'time', 'engaging', 'want', 'minimize', 'live', 'avoid', 'place', 'hacked', 'kind', 'point', 'favorite', 'remains', 'visualization', 'decision', 'tree', 'powerful', 'concept', 'moment', 'breath', 'contains', 'imperfect', 'wrong', 'living', 'state', 'perpetual', 'worse', 'built', 'actually', 'eradicate', 'world', 'right', 'work', 'learn', 'cheat', 'review', 'main', 'thrust', 'stayer', 'leaver', 'political', 'tension', 'slinghot', 'maneuver', 'worth', 'reading', 'surfer', 'love', 'freya', 'finding', 'surfing', 'wave', 'conclusion', 'wanted', 'people', 'finally', 'outside', 'hole', 'pointed', 'sure', 'self', 'published', 'biasing', 'editing', 'feel', 'writing', 'great', 'thing', 'cleared', 'fully', 'sense', 'major', 'thurman', 'felt', 'need', 'clear', 'accomplished', 'nuclear', 'nano', 'wasteland', 'happened', 'silo', 'went', 'expecting', 'broken', 'waiting', 'hugh', 'story', 'later', 'happens', 'destroyed', 'power', 'server', 'room', 'provide', 'including', 'guidance', 'head', 'year', 'mystery', 'dead', 'explained', 'guessing', 'kept', 'healing', 'anna', 'killed', 'donald', 'juliet', 'kyle', 'ended', 'sadly', 'reflection', 'necessary', 'uncertainty', 'creep', 'role', 'eliminate', 'doubt', 'delicate', 'balance', 'opening', 'holston', 'brilliant', 'sucked', 'immediately', 'hard', 'quantum', 'computing', 'encoding', 'ancient', 'code', 'heart', 'text', 'contained', 'algorithm', 'trouble', 'buying', 'alif', 'dina', 'relationship', 'witnessed', 'warm', 'morris', 'courage', 'transform', 'change', 'word', 'easy', 'dictate', 'path', 'charlie', 'crime', 'fascinating', 'similar', 'thief', 'past', 'difficulty', 'leave', 'commodore', 'employment', 'separation', 'roman', 'sent', 'elisabeth', 'huge', 'company', 'check', 'dollar', 'write', 'accounting', 'sheet', 'accrual', 'personal', 'cashed', 'raise', 'flag', 'okay', 'danger', 'safe', 'kill', 'tried', 'hurt', 'said', 'holding', 'coming', 'angel', 'ambiguity', 'taken', 'friend', 'scholar', 'report', 'journal', 'novel', 'partially', 'resolved', 'offred', 'maine', 'trace', 'parallel', 'moira', 'preferred', 'romance', 'competent', 'woodruff', 'sister', 'owned', 'ranch', 'circuit', 'remain', 'model', 'liked', 'strong', 'independent', 'demand', 'henry', 'proposed', 'acceptance', 'representation', 'theme', 'morphed', 'identity', 'narrator', 'shifted', 'speaking', 'culmination', 'mother', 'saying', 'half', 'nationality', 'positive', 'transforming', 'important', 'freedom', 'independence', 'blood', 'brother', 'commissar', 'charge', 'education', 'lead', 'start', 'revolution', 'grab', 'hope', 'torture', 'scene', 'wondered', 'intended', 'judge', 'communist', 'working', 'double', 'agent', 'en ...
# {'folding': <gensim.models.keyedvectors.Vocab at 0x7efd1350f310>,
#  'proton': <gensim.models.keyedvectors.Vocab at 0x7efd1350f950>,
#  'dimension': <gensim.models.keyedvectors.Vocab at 0x7efd1350f750>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x7efd1350f350>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x7efd1350ff90>,
#  'stuff': <gensim.models.keyedvectors.Vocab at 0x7efd1350fc10>,
#  'interesting': <gensim.models.keyedvectors.Vocab at 0x7efd1350f490>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x7efd1350fc90>,
#  'seti': <gensim.models.keyedvectors.Vocab at 0x7efd1350ff10>,
#  'station': <gensim.models.keyedvectors.Vocab at 0x7efd1350fd50>,
#  'received': <gensim.models.keyedvectors.Vocab at 0x7efd1350f910>,
#  'message': <gensim.models.keyedvectors.Vocab at 0x7efd1350fb50>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x7efd1350fb90>,
#  'monitoring': <gensim.models.keyedvectors.Vocab at 0x7efd1350f550>,
#  'answering': <gensim.models.keyedvectors.Vocab at 0x7efd1350f710>,
#  'signal': <gensim.models.keyedvectors.Vocab at 0x7efd1350f050>,
#  'disillusioned': <gensim.models.keyedvectors.Vocab at 0x7efd1350fe90>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x7efd1350fe10>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x7efd1350f790>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7efd1350fc50>,
#  'human': <gensim.models.keyedvectors.Vocab at 0x7efd1350fe50>,
#  'reaction': <gensim.models.keyedvectors.Vocab at 0x7efd1350f590>,
#  'discovering': <gensim.models.keyedvectors.Vocab at 0x7efd1350f210>,
#  'alien': <gensim.models.keyedvectors.Vocab at 0x7efd1350fd90>,
#  'civilization': <gensim.models.keyedvectors.Vocab at 0x7efd1350fb10>,
#  'hostile': <gensim.models.keyedvectors.Vocab at 0x7efd1350f650>,
#  'enders': <gensim.models.keyedvectors.Vocab at 0x7efd1350fd10>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x7efd1350fa50>,
#  'band': <gensim.models.keyedvectors.Vocab at 0x7efd1350fa90>,
#  'unveiled': <gensim.models.keyedvectors.Vocab at 0x7efd1350f290>,
#  'trisolaran': <gensim.models.keyedvectors.Vocab at 0x7efd1350f250>,
#  'culture': <gensim.models.keyedvectors.Vocab at 0x7efd1350f810>,
#  'smart': <gensim.models.keyedvectors.Vocab at 0x7efd1350fa10>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x7efd1350f850>,
#  'empathy': <gensim.models.keyedvectors.Vocab at 0x7efd134edf50>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x7efd134ed450>,
#  'gone': <gensim.models.keyedvectors.Vocab at 0x7efd134ed750>,
#  'century': <gensim.models.keyedvectors.Vocab at 0x7efd134ede10>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7efd134ed550>,
#  'body': <gensim.models.keyedvectors.Vocab at 0x7efd134ed710>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x7efd134ed310>,
#  'unsolvable': <gensim.models.keyedvectors.Vocab at 0x7efd134edcd0>,
#  'math': <gensim.models.keyedvectors.Vocab at 0x7efd134ed410>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x7efd134edfd0>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x7efd134ed050>,
#  'loved': <gensim.models.keyedvectors.Vocab at 0x7efd134ed910>,
#  'quote': <gensim.models.keyedvectors.Vocab at 0x7efd134edad0>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7efd134ed510>,
#  'history': <gensim.models.keyedvectors.Vocab at 0x7efd134edbd0>,
#  'scientific': <gensim.models.keyedvectors.Vocab at 0x7efd134eded0>,
#  'progress': <gensim.models.keyedvectors.Vocab at 0x7efd134909d0>,
#  'smashed': <gensim.models.keyedvectors.Vocab at 0x7efd13490390>,
#  'apart': <gensim.models.keyedvectors.Vocab at 0x7efd13490090>,
#  'accelerator': <gensim.models.keyedvectors.Vocab at 0x7efd13490290>,
#  'physicist': <gensim.models.keyedvectors.Vocab at 0x7efd13490050>,
#  'neutron': <gensim.models.keyedvectors.Vocab at 0x7efd134901d0>,
#  'electron': <gensim.models.keyedvectors.Vocab at 0x7efd134900d0>,
#  'probably': <gensim.models.keyedvectors.Vocab at 0x7efd13490350>,
#  'fewer': <gensim.models.keyedvectors.Vocab at 0x7efd13490450>,
#  'million': <gensim.models.keyedvectors.Vocab at 0x7efd134906d0>,
#  'collision': <gensim.models.keyedvectors.Vocab at 0x7efd134905d0>,
#  'intelligence': <gensim.models.keyedvectors.Vocab at 0x7efd13490890>,
#  'microcosmos': <gensim.models.keyedvectors.Vocab at 0x7efd134903d0>,
#  'fact': <gensim.models.keyedvectors.Vocab at 0x7efd13490590>,
#  'nature': <gensim.models.keyedvectors.Vocab at 0x7efd13490690>,
#  'destruction': <gensim.models.keyedvectors.Vocab at 0x7efd13490c50>,
#  'universe': <gensim.models.keyedvectors.Vocab at 0x7efd13490fd0>,
#  'happening': <gensim.models.keyedvectors.Vocab at 0x7efd13490850>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x7efd13490ad0>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x7efd13490c90>,
#  'decay': <gensim.models.keyedvectors.Vocab at 0x7efd13490150>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7efd13490b50>,
#  'energy': <gensim.models.keyedvectors.Vocab at 0x7efd13490e50>,
#  'cosmic': <gensim.models.keyedvectors.Vocab at 0x7efd13490dd0>,
#  'entering': <gensim.models.keyedvectors.Vocab at 0x7efd13490cd0>,
#  'atmosphere': <gensim.models.keyedvectors.Vocab at 0x7efd13490f50>,
#  'destroy': <gensim.models.keyedvectors.Vocab at 0x7efd13490f90>,
#  'thousand': <gensim.models.keyedvectors.Vocab at 0x7efd13490a50>,
#  'miniature': <gensim.models.keyedvectors.Vocab at 0x7efd13490d50>,
#  'discussed': <gensim.models.keyedvectors.Vocab at 0x7efd13490190>,
#  'spoiler': <gensim.models.keyedvectors.Vocab at 0x7efd134908d0>,
#  'choice': <gensim.models.keyedvectors.Vocab at 0x7efd13490950>,
#  'regret': <gensim.models.keyedvectors.Vocab at 0x7efd13490a90>,
#  'chasing': <gensim.models.keyedvectors.Vocab at 0x7efd13490490>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x7efd13490ed0>,
#  'dream': <gensim.models.keyedvectors.Vocab at 0x7efd13490790>,
#  'focus': <gensim.models.keyedvectors.Vocab at 0x7efd13490550>,
#  'career': <gensim.models.keyedvectors.Vocab at 0x7efd134907d0>,
#  'jason': <gensim.models.keyedvectors.Vocab at 0x7efd13490250>,
#  'clearly': <gensim.models.keyedvectors.Vocab at 0x7efd134902d0>,
#  'author': <gensim.models.keyedvectors.Vocab at 0x7efd13490b90>,
#  'trying': <gensim.models.keyedvectors.Vocab at 0x7efd13490d90>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x7efd13490e90>,
#  'optimize': <gensim.models.keyedvectors.Vocab at 0x7efd13490990>,
#  'happiness': <gensim.models.keyedvectors.Vocab at 0x7efd13490650>,
#  'rate': <gensim.models.keyedvectors.Vocab at 0x7efd13490bd0>,
#  'physic': <gensim.models.keyedvectors.Vocab at 0x7efd13490750>,
#  'teacher': <gensim.models.keyedvectors.Vocab at 0x7efd134fd910>,
#  'community': <gensim.models.keyedvectors.Vocab at 0x7efd134fd610>,
#  'college': <gensim.models.keyedvectors.Vocab at 0x7efd134fd2d0>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x7efd134fde10>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x7efd134fdf10>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x7efd134fdc50>,
#  'snarky': <gensim.models.keyedvectors.Vocab at 0x7efd134fdad0>,
#  'certainly': <gensim.models.keyedvectors.Vocab at 0x7efd134fdf50>,
#  'meaning': <gensim.models.keyedvectors.Vocab at 0x7efd134fd810>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x7efd134fd0d0>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x7efd134fd410>,
#  'shallow': <gensim.models.keyedvectors.Vocab at 0x7efd134fdb50>,
#  'character': <gensim.models.keyedvectors.Vocab at 0x7efd134fdd10>,
#  'fairly': <gensim.models.keyedvectors.Vocab at 0x7efd134fdc10>,
#  'daniela': <gensim.models.keyedvectors.Vocab at 0x7efd134fded0>,
#  'perfect': <gensim.models.keyedvectors.Vocab at 0x7efd134fd510>,
#  'wife': <gensim.models.keyedvectors.Vocab at 0x7efd134920d0>,
#  'ryan': <gensim.models.keyedvectors.Vocab at 0x7efd134921d0>,
#  'antithesis': <gensim.models.keyedvectors.Vocab at 0x7efd13492190>,
#  'amanda': <gensim.models.keyedvectors.Vocab at 0x7efd13492090>,
#  'loyal': <gensim.models.keyedvectors.Vocab at 0x7efd13492590>,
#  'traveling': <gensim.models.keyedvectors.Vocab at 0x7efd134924d0>,
#  'companion': <gensim.models.keyedvectors.Vocab at 0x7efd13492490>,
#  'plus': <gensim.models.keyedvectors.Vocab at 0x7efd13492110>,
#  'weak': <gensim.models.keyedvectors.Vocab at 0x7efd13492410>,
#  'science': <gensim.models.keyedvectors.Vocab at 0x7efd13492210>,
#  'star': <gensim.models.keyedvectors.Vocab at 0x7efd13492310>,
#  'read': <gensim.models.keyedvectors.Vocab at 0x7efd13492390>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7efd13492290>,
#  'engaging': <gensim.models.keyedvectors.Vocab at 0x7efd134922d0>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7efd13492710>,
#  'minimize': <gensim.models.keyedvectors.Vocab at 0x7efd13492510>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x7efd134926d0>,
#  'avoid': <gensim.models.keyedvectors.Vocab at 0x7efd13492790>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x7efd13492690>,
#  'hacked': <gensim.models.keyedvectors.Vocab at 0x7efd134923d0>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x7efd13492610>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x7efd134925d0>,
#  'favorite': <gensim.models.keyedvectors.Vocab at 0x7efd13492990>,
#  'remains': <gensim.models.keyedvectors.Vocab at 0x7efd13492890>,
#  'visualization': <gensim.models.keyedvectors.Vocab at 0x7efd13492910>,
#  'decision': <gensim.models.keyedvectors.Vocab at 0x7efd134928d0>,
#  'tree': <gensim.models.keyedvectors.Vocab at 0x7efd13492b90>,
#  'powerful': <gensim.models.keyedvectors.Vocab at 0x7efd13492b10>,
#  'concept': <gensim.models.keyedvectors.Vocab at 0x7efd13492810>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x7efd13492ad0>,
#  'breath': <gensim.models.keyedvectors.Vocab at 0x7efd13492a90>,
#  'contains': <gensim.models.keyedvectors.Vocab at 0x7efd134927d0>,
#  'imperfect': <gensim.models.keyedvectors.Vocab at 0x7efd13492a10>,
#  'wrong': <gensim.models.keyedvectors.Vocab at 0x7efd13492d90>,
#  'living': <gensim.models.keyedvectors.Vocab at 0x7efd134929d0>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x7efd13492cd0>,
#  'perpetual': <gensim.models.keyedvectors.Vocab at 0x7efd13492d10>,
#  'worse': <gensim.models.keyedvectors.Vocab at 0x7efd13492c90>,
#  'built': <gensim.models.keyedvectors.Vocab at 0x7efd13492c10>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x7efd13492f90>,
#  'eradicate': <gensim.models.keyedvectors.Vocab at 0x7efd13492f10>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7efd13492ed0>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x7efd13492e90>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7efd13492e10>,
#  'learn': <gensim.models.keyedvectors.Vocab at 0x7efd13492dd0>,
#  'cheat': <gensim.models.keyedvectors.Vocab at 0x7efd13492bd0>,
#  'review': <gensim.models.keyedvectors.Vocab at 0x7efd13492fd0>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x7efd134961d0>,
#  'thrust': <gensim.models.keyedvectors.Vocab at 0x7efd13496150>,
#  'stayer': <gensim.models.keyedvectors.Vocab at 0x7efd13496110>,
#  'leaver': <gensim.models.keyedvectors.Vocab at 0x7efd134960d0>,
#  'political': <gensim.models.keyedvectors.Vocab at 0x7efd134963d0>,
#  'tension': <gensim.models.keyedvectors.Vocab at 0x7efd13496350>,
#  'slinghot': <gensim.models.keyedvectors.Vocab at 0x7efd134962d0>,
#  'maneuver': <gensim.models.keyedvectors.Vocab at 0x7efd13496050>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x7efd13496310>,
#  'reading': <gensim.models.keyedvectors.Vocab at 0x7efd13496250>,
#  'surfer': <gensim.models.keyedvectors.Vocab at 0x7efd134965d0>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x7efd13496550>,
#  'freya': <gensim.models.keyedvectors.Vocab at 0x7efd13496210>,
#  'finding': <gensim.models.keyedvectors.Vocab at 0x7efd13496510>,
#  'surfing': <gensim.models.keyedvectors.Vocab at 0x7efd134964d0>,
#  'wave': <gensim.models.keyedvectors.Vocab at 0x7efd13496450>,
#  'conclusion': <gensim.models.keyedvectors.Vocab at 0x7efd13496750>,
#  'wanted': <gensim.models.keyedvectors.Vocab at 0x7efd13496710>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7efd134966d0>,
#  'finally': <gensim.models.keyedvectors.Vocab at 0x7efd13496410>,
#  'outside': <gensim.models.keyedvectors.Vocab at 0x7efd134967d0>,
#  'hole': <gensim.models.keyedvectors.Vocab at 0x7efd13496650>,
#  'pointed': <gensim.models.keyedvectors.Vocab at 0x7efd134969d0>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x7efd13496950>,
#  'self': <gensim.models.keyedvectors.Vocab at 0x7efd13496610>,
#  'published': <gensim.models.keyedvectors.Vocab at 0x7efd13496910>,
#  'biasing': <gensim.models.keyedvectors.Vocab at 0x7efd134968d0>,
#  'editing': <gensim.models.keyedvectors.Vocab at 0x7efd13496850>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x7efd13496bd0>,
#  'writing': <gensim.models.keyedvectors.Vocab at 0x7efd13496b50>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7efd13496b10>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x7efd13496ad0>,
#  'cleared': <gensim.models.keyedvectors.Vocab at 0x7efd13496810>,
#  'fully': <gensim.models.keyedvectors.Vocab at 0x7efd13496a50>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x7efd13496dd0>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x7efd13496d50>,
#  'thurman': <gensim.models.keyedvectors.Vocab at 0x7efd13496a10>,
#  'felt': <gensim.models.keyedvectors.Vocab at 0x7efd13496d10>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7efd13496cd0>,
#  'clear': <gensim.models.keyedvectors.Vocab at 0x7efd13496c50>,
#  'accomplished': <gensim.models.keyedvectors.Vocab at 0x7efd13496f50>,
#  'nuclear': <gensim.models.keyedvectors.Vocab at 0x7efd13496f10>,
#  'nano': <gensim.models.keyedvectors.Vocab at 0x7efd13496e90>,
#  'wasteland': <gensim.models.keyedvectors.Vocab at 0x7efd13496c10>,
#  'happened': <gensim.models.keyedvectors.Vocab at 0x7efd13496f90>,
#  'silo': <gensim.models.keyedvectors.Vocab at 0x7efd13496e50>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x7efd13497250>,
#  'expecting': <gensim.models.keyedvectors.Vocab at 0x7efd134971d0>,
#  'broken': <gensim.models.keyedvectors.Vocab at 0x7efd13497050>,
#  'waiting': <gensim.models.keyedvectors.Vocab at 0x7efd13497190>,
#  'hugh': <gensim.models.keyedvectors.Vocab at 0x7efd13497150>,
#  'story': <gensim.models.keyedvectors.Vocab at 0x7efd134970d0>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x7efd13497450>,
#  'happens': <gensim.models.keyedvectors.Vocab at 0x7efd134973d0>,
#  'destroyed': <gensim.models.keyedvectors.Vocab at 0x7efd13497390>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x7efd13497350>,
#  'server': <gensim.models.keyedvectors.Vocab at 0x7efd13497090>,
#  'room': <gensim.models.keyedvectors.Vocab at 0x7efd134972d0>,
#  'provide': <gensim.models.keyedvectors.Vocab at 0x7efd13497650>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x7efd134975d0>,
#  'guidance': <gensim.models.keyedvectors.Vocab at 0x7efd13497290>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x7efd13497590>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x7efd13497550>,
#  'mystery': <gensim.models.keyedvectors.Vocab at 0x7efd134974d0>,
#  'dead': <gensim.models.keyedvectors.Vocab at 0x7efd13497850>,
#  'explained': <gensim.models.keyedvectors.Vocab at 0x7efd134977d0>,
#  'guessing': <gensim.models.keyedvectors.Vocab at 0x7efd13497790>,
#  'kept': <gensim.models.keyedvectors.Vocab at 0x7efd13497750>,
#  'healing': <gensim.models.keyedvectors.Vocab at 0x7efd13497490>,
#  'anna': <gensim.models.keyedvectors.Vocab at 0x7efd134976d0>,
#  'killed': <gensim.models.keyedvectors.Vocab at 0x7efd13497a50>,
#  'donald': <gensim.models.keyedvectors.Vocab at 0x7efd134979d0>,
#  'juliet': <gensim.models.keyedvectors.Vocab at 0x7efd13497690>,
#  'kyle': <gensim.models.keyedvectors.Vocab at 0x7efd13497990>,
#  'ended': <gensim.models.keyedvectors.Vocab at 0x7efd13497950>,
#  'sadly': <gensim.models.keyedvectors.Vocab at 0x7efd134978d0>,
#  'reflection': <gensim.models.keyedvectors.Vocab at 0x7efd13497c50>,
#  'necessary': <gensim.models.keyedvectors.Vocab at 0x7efd13497bd0>,
#  'uncertainty': <gensim.models.keyedvectors.Vocab at 0x7efd13497b90>,
#  'creep': <gensim.models.keyedvectors.Vocab at 0x7efd13497b50>,
#  'role': <gensim.models.keyedvectors.Vocab at 0x7efd13497890>,
#  'eliminate': <gensim.models.keyedvectors.Vocab at 0x7efd13497e50>,
#  'doubt': <gensim.models.keyedvectors.Vocab at 0x7efd134ed350>,
#  'delicate': <gensim.models.keyedvectors.Vocab at 0x7efd134edc10>,
#  'balance': <gensim.models.keyedvectors.Vocab at 0x7efd134edb10>,
#  'opening': <gensim.models.keyedvectors.Vocab at 0x7efd134ede50>,
#  'holston': <gensim.models.keyedvectors.Vocab at 0x7efd134ed1d0>,
#  'brilliant': <gensim.models.keyedvectors.Vocab at 0x7efd134ed210>,
#  'sucked': <gensim.models.keyedvectors.Vocab at 0x7efd134ed110>,
#  'immediately': <gensim.models.keyedvectors.Vocab at 0x7efd134ed6d0>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x7efd134ed0d0>,
#  'quantum': <gensim.models.keyedvectors.Vocab at 0x7efd134ed2d0>,
#  'computing': <gensim.models.keyedvectors.Vocab at 0x7efd134ed250>,
#  'encoding': <gensim.models.keyedvectors.Vocab at 0x7efd134ed4d0>,
#  'ancient': <gensim.models.keyedvectors.Vocab at 0x7efd134ed3d0>,
#  'code': <gensim.models.keyedvectors.Vocab at 0x7efd134ed7d0>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x7efd134ed150>,
#  'text': <gensim.models.keyedvectors.Vocab at 0x7efd134ed5d0>,
#  'contained': <gensim.models.keyedvectors.Vocab at 0x7efd13497dd0>,
#  'algorithm': <gensim.models.keyedvectors.Vocab at 0x7efd13497ad0>,
#  'trouble': <gensim.models.keyedvectors.Vocab at 0x7efd13497a90>,
#  'buying': <gensim.models.keyedvectors.Vocab at 0x7efd13497d90>,
#  'alif': <gensim.models.keyedvectors.Vocab at 0x7efd13497d50>,
#  'dina': <gensim.models.keyedvectors.Vocab at 0x7efd13497cd0>,
#  'relationship': <gensim.models.keyedvectors.Vocab at 0x7efd13497fd0>,
#  'witnessed': <gensim.models.keyedvectors.Vocab at 0x7efd13497f90>,
#  'warm': <gensim.models.keyedvectors.Vocab at 0x7efd13497f50>,
#  'morris': <gensim.models.keyedvectors.Vocab at 0x7efd13497ed0>,
#  'courage': <gensim.models.keyedvectors.Vocab at 0x7efd13497c90>,
#  'transform': <gensim.models.keyedvectors.Vocab at 0x7efd13497e90>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x7efd1349a090>,
#  'word': <gensim.models.keyedvectors.Vocab at 0x7efd1349a290>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x7efd1349a210>,
#  'dictate': <gensim.models.keyedvectors.Vocab at 0x7efd1349a1d0>,
#  'path': <gensim.models.keyedvectors.Vocab at 0x7efd1349a190>,
#  'charlie': <gensim.models.keyedvectors.Vocab at 0x7efd1349a110>,
#  'crime': <gensim.models.keyedvectors.Vocab at 0x7efd1349a490>,
#  'fascinating': <gensim.models.keyedvectors.Vocab at 0x7efd1349a410>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x7efd1349a3d0>,
#  'thief': <gensim.models.keyedvectors.Vocab at 0x7efd1349a390>,
#  'past': <gensim.models.keyedvectors.Vocab at 0x7efd1349a0d0>,
#  'difficulty': <gensim.models.keyedvectors.Vocab at 0x7efd1349a690>,
#  'leave': <gensim.models.keyedvectors.Vocab at 0x7efd1349a310>,
#  'commodore': <gensim.models.keyedvectors.Vocab at 0x7efd1349a2d0>,
#  'employment': <gensim.models.keyedvectors.Vocab at 0x7efd1349a610>,
#  'separation': <gensim.models.keyedvectors.Vocab at 0x7efd1349a5d0>,
#  'roman': <gensim.models.keyedvectors.Vocab at 0x7efd1349a590>,
#  'sent': <gensim.models.keyedvectors.Vocab at 0x7efd1349a510>,
#  'elisabeth': <gensim.models.keyedvectors.Vocab at 0x7efd1349a890>,
#  'huge': <gensim.models.keyedvectors.Vocab at 0x7efd1349a810>,
#  'company': <gensim.models.keyedvectors.Vocab at 0x7efd1349a7d0>,
#  'check': <gensim.models.keyedvectors.Vocab at 0x7efd1349a4d0>,
#  'dollar': <gensim.models.keyedvectors.Vocab at 0x7efd1349a710>,
#  'write': <gensim.models.keyedvectors.Vocab at 0x7efd1349a6d0>,
#  'accounting': <gensim.models.keyedvectors.Vocab at 0x7efd1349aa90>,
#  'sheet': <gensim.models.keyedvectors.Vocab at 0x7efd1349a790>,
#  'accrual': <gensim.models.keyedvectors.Vocab at 0x7efd1349aa10>,
#  'personal': <gensim.models.keyedvectors.Vocab at 0x7efd1349a9d0>,
#  'cashed': <gensim.models.keyedvectors.Vocab at 0x7efd1349a990>,
#  'raise': <gensim.models.keyedvectors.Vocab at 0x7efd1349ac90>,
#  'flag': <gensim.models.keyedvectors.Vocab at 0x7efd1349abd0>,
#  'okay': <gensim.models.keyedvectors.Vocab at 0x7efd1349ab90>,
#  'danger': <gensim.models.keyedvectors.Vocab at 0x7efd1349a8d0>,
#  'safe': <gensim.models.keyedvectors.Vocab at 0x7efd1349a910>,
#  'kill': <gensim.models.keyedvectors.Vocab at 0x7efd1349ab10>,
#  'tried': <gensim.models.keyedvectors.Vocab at 0x7efd1349aad0>,
#  'hurt': <gensim.models.keyedvectors.Vocab at 0x7efd1349ae90>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x7efd1349ac10>,
#  'holding': <gensim.models.keyedvectors.Vocab at 0x7efd1349ae10>,
#  'coming': <gensim.models.keyedvectors.Vocab at 0x7efd1349add0>,
#  'angel': <gensim.models.keyedvectors.Vocab at 0x7efd1349ad90>,
#  'ambiguity': <gensim.models.keyedvectors.Vocab at 0x7efd1349ad10>,
#  'taken': <gensim.models.keyedvectors.Vocab at 0x7efd1349afd0>,
#  'friend': <gensim.models.keyedvectors.Vocab at 0x7efd1349acd0>,
#  'scholar': <gensim.models.keyedvectors.Vocab at 0x7efd1349af10>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x7efd1349aed0>,
#  'journal': <gensim.models.keyedvectors.Vocab at 0x7efd1349af90>,
#  'novel': <gensim.models.keyedvectors.Vocab at 0x7efd134f64d0>,
#  'partially': <gensim.models.keyedvectors.Vocab at 0x7efd134f6550>,
#  'resolved': <gensim.models.keyedvectors.Vocab at 0x7efd134f6510>,
#  'offred': <gensim.models.keyedvectors.Vocab at 0x7efd134f6250>,
#  'maine': <gensim.models.keyedvectors.Vocab at 0x7efd134f68d0>,
#  'trace': <gensim.models.keyedvectors.Vocab at 0x7efd134f6710>,
#  'parallel': <gensim.models.keyedvectors.Vocab at 0x7efd134f6fd0>,
#  'moira': <gensim.models.keyedvectors.Vocab at 0x7efd134f6650>,
#  'preferred': <gensim.models.keyedvectors.Vocab at 0x7efd134f6b10>,
#  'romance': <gensim.models.keyedvectors.Vocab at 0x7efd134f6d50>,
#  'competent': <gensim.models.keyedvectors.Vocab at 0x7efd134f6f10>,
#  'woodruff': <gensim.models.keyedvectors.Vocab at 0x7efd134f6450>,
#  'sister': <gensim.models.keyedvectors.Vocab at 0x7efd134f6e10>,
#  'owned': <gensim.models.keyedvectors.Vocab at 0x7efd134f6a10>,
#  'ranch': <gensim.models.keyedvectors.Vocab at 0x7efd134f6210>,
#  'circuit': <gensim.models.keyedvectors.Vocab at 0x7efd134f65d0>,
#  'remain': <gensim.models.keyedvectors.Vocab at 0x7efd134f69d0>,
#  'model': <gensim.models.keyedvectors.Vocab at 0x7efd134f6610>,
#  'liked': <gensim.models.keyedvectors.Vocab at 0x7efd134f6bd0>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x7efd134f6f50>,
#  'independent': <gensim.models.keyedvectors.Vocab at 0x7efd134f6110>,
#  'demand': <gensim.models.keyedvectors.Vocab at 0x7efd134f6ad0>,
#  'henry': <gensim.models.keyedvectors.Vocab at 0x7efd134f6850>,
#  'proposed': <gensim.models.keyedvectors.Vocab at 0x7efd134f6950>,
#  'acceptance': <gensim.models.keyedvectors.Vocab at 0x7efd134f6b50>,
#  'representation': <gensim.models.keyedvectors.Vocab at 0x7efd134f61d0>,
#  'theme': <gensim.models.keyedvectors.Vocab at 0x7efd134f6810>,
#  'morphed': <gensim.models.keyedvectors.Vocab at 0x7efd134f6c10>,
#  'identity': <gensim.models.keyedvectors.Vocab at 0x7efd134f6dd0>,
#  'narrator': <gensim.models.keyedvectors.Vocab at 0x7efd134f6d10>,
#  'shifted': <gensim.models.keyedvectors.Vocab at 0x7efd134f6c50>,
#  'speaking': <gensim.models.keyedvectors.Vocab at 0x7efd134f62d0>,
#  'culmination': <gensim.models.keyedvectors.Vocab at 0x7efd134f6910>,
#  'mother': <gensim.models.keyedvectors.Vocab at 0x7efd134f6a50>,
#  'saying': <gensim.models.keyedvectors.Vocab at 0x7efd134f6ed0>,
#  'half': <gensim.models.keyedvectors.Vocab at 0x7efd134f6750>,
#  'nationality': <gensim.models.keyedvectors.Vocab at 0x7efd134f6e50>,
#  'positive': <gensim.models.keyedvectors.Vocab at 0x7efd134f63d0>,
#  'transforming': <gensim.models.keyedvectors.Vocab at 0x7efd134f6cd0>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x7efd134f6410>,
#  'freedom': <gensim.models.keyedvectors.Vocab at 0x7efd134f6350>,
#  'independence': <gensim.models.keyedvectors.Vocab at 0x7efd134f6050>,
#  'blood': <gensim.models.keyedvectors.Vocab at 0x7efd134f6150>,
#  'brother': <gensim.models.keyedvectors.Vocab at 0x7efd134f67d0>,
#  'commissar': <gensim.models.keyedvectors.Vocab at 0x7efd134f6310>,
#  'charge': <gensim.models.keyedvectors.Vocab at 0x7efd134f66d0>,
#  'education': <gensim.models.keyedvectors.Vocab at 0x7efd134f60d0>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x7efd134ea210>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x7efd134eab10>,
#  'revolution': <gensim.models.keyedvectors.Vocab at 0x7efd134eab90>,
#  'grab': <gensim.models.keyedvectors.Vocab at 0x7efd134ea090>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x7efd134ea910>,
#  'torture': <gensim.models.keyedvectors.Vocab at 0x7efd134eaa10>,
#  'scene': <gensim.models.keyedvectors.Vocab at 0x7efd134ea110>,
#  'wondered': <gensim.models.keyedvectors.Vocab at 0x7efd134eabd0>,
#  'intended': <gensim.models.keyedvectors.Vocab at 0x7efd134eac10>,
#  'judge': <gensim.models.keyedvectors.Vocab at 0x7efd134eac90>,
#  'communist': <gensim.models.keyedvectors.Vocab at 0x7efd134eaad0>,
#  'working': <gensim.models.keyedvectors.Vocab at 0x7efd134ea190>,
#  'double': <gensim.models.keyedvectors.Vocab at 0x7efd134eafd0>,
#  'agent': <gensim.models.keyedvectors.Vocab at 0x7efd134eadd0>,
#  'ending': <gensim.models.keyedvectors.Vocab at 0x7efd134ead10>,
#  'emphasis': <gensim.models.keyedvectors.Vocab at 0x7efd134eae10>,
#  'manual': <gensim.models.keyedvectors.Vocab at 0x7efd134ea490>,
#  'orchestrate': <gensim.models.keyedvectors.Vocab at 0x7efd134ead90>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x7efd134ea690>,
#  'national': <gensim.models.keyedvectors.Vocab at 0x7efd134ea590>,
#  'judgment': <gensim.models.keyedvectors.Vocab at 0x7efd134ea310>,
#  'council': <gensim.models.keyedvectors.Vocab at 0x7efd134ea8d0>,
#  'abstract': <gensim.models.keyedvectors.Vocab at 0x7efd134ea6d0>,
#  'earlier': <gensim.models.keyedvectors.Vocab at 0x7efd134ea410>,
#  'klan': <gensim.models.keyedvectors.Vocab at 0x7efd134ea1d0>,
#  'involved': <gensim.models.keyedvectors.Vocab at 0x7efd134ea810>,
#  'temper': <gensim.models.keyedvectors.Vocab at 0x7efd134eaa90>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x7efd134ea710>,
#  'sellout': <gensim.models.keyedvectors.Vocab at 0x7efd134ea3d0>,
#  'jean': <gensim.models.keyedvectors.Vocab at 0x7efd134ea390>,
#  'louise': <gensim.models.keyedvectors.Vocab at 0x7efd134eaf90>,
#  'praise': <gensim.models.keyedvectors.Vocab at 0x7efd134ea610>,
#  'able': <gensim.models.keyedvectors.Vocab at 0x7efd134ea290>,
#  'judgement': <gensim.models.keyedvectors.Vocab at 0x7efd134eae90>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x7efd134ea5d0>,
#  'believable': <gensim.models.keyedvectors.Vocab at 0x7efd134ea0d0>,
#  'spoke': <gensim.models.keyedvectors.Vocab at 0x7efd134ea990>,
#  'intimate': <gensim.models.keyedvectors.Vocab at 0x7efd1350a590>,
#  'leaving': <gensim.models.keyedvectors.Vocab at 0x7efd1350a3d0>,
#  'likely': <gensim.models.keyedvectors.Vocab at 0x7efd1350a050>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x7efd1350a8d0>,
#  'lack': <gensim.models.keyedvectors.Vocab at 0x7efd1350a0d0>,
#  'directness': <gensim.models.keyedvectors.Vocab at 0x7efd1350a710>,
#  'encounter': <gensim.models.keyedvectors.Vocab at 0x7efd1350ab10>,
#  'lucie': <gensim.models.keyedvectors.Vocab at 0x7efd1350a6d0>,
#  'memory': <gensim.models.keyedvectors.Vocab at 0x7efd1350aa90>,
#  'previous': <gensim.models.keyedvectors.Vocab at 0x7efd1350a690>,
#  'imagine': <gensim.models.keyedvectors.Vocab at 0x7efd1350a250>,
#  'finance': <gensim.models.keyedvectors.Vocab at 0x7efd1350a310>,
#  'shift': <gensim.models.keyedvectors.Vocab at 0x7efd1350a610>,
#  'flattered': <gensim.models.keyedvectors.Vocab at 0x7efd1350a410>,
#  'theodore': <gensim.models.keyedvectors.Vocab at 0x7efd1350acd0>,
#  'attention': <gensim.models.keyedvectors.Vocab at 0x7efd1350abd0>,
#  'rejecting': <gensim.models.keyedvectors.Vocab at 0x7efd1350a910>,
#  'sudden': <gensim.models.keyedvectors.Vocab at 0x7efd1350a190>,
#  'mary': <gensim.models.keyedvectors.Vocab at 0x7efd1350af10>,
#  'disillusionment': <gensim.models.keyedvectors.Vocab at 0x7efd1350add0>,
#  'northern': <gensim.models.keyedvectors.Vocab at 0x7efd1350a090>,
#  'society': <gensim.models.keyedvectors.Vocab at 0x7efd1350ac10>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x7efd1350ad10>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x7efd1350a510>,
#  'convincingly': <gensim.models.keyedvectors.Vocab at 0x7efd1350ae90>,
#  'presented': <gensim.models.keyedvectors.Vocab at 0x7efd1350a890>,
#  'information': <gensim.models.keyedvectors.Vocab at 0x7efd1350a7d0>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x7efd1350a9d0>,
#  'sharing': <gensim.models.keyedvectors.Vocab at 0x7efd1350ad90>,
#  'control': <gensim.models.keyedvectors.Vocab at 0x7efd1350a2d0>,
#  'union': <gensim.models.keyedvectors.Vocab at 0x7efd1350a150>,
#  'army': <gensim.models.keyedvectors.Vocab at 0x7efd1350aed0>,
#  'activity': <gensim.models.keyedvectors.Vocab at 0x7efd1350aad0>,
#  'fetched': <gensim.models.keyedvectors.Vocab at 0x7efd1350af90>,
#  'especially': <gensim.models.keyedvectors.Vocab at 0x7efd1350a810>,
#  'withhold': <gensim.models.keyedvectors.Vocab at 0x7efd1350a390>,
#  'prolonged': <gensim.models.keyedvectors.Vocab at 0x7efd1350aa10>,
#  'premature': <gensim.models.keyedvectors.Vocab at 0x7efd1350a790>,
#  'victory': <gensim.models.keyedvectors.Vocab at 0x7efd1350ab90>,
#  'slavery': <gensim.models.keyedvectors.Vocab at 0x7efd1350a1d0>,
#  'intact': <gensim.models.keyedvectors.Vocab at 0x7efd1350a990>,
#  'strained': <gensim.models.keyedvectors.Vocab at 0x7efd134d8a50>,
#  'satisfying': <gensim.models.keyedvectors.Vocab at 0x7efd1349b0d0>,
#  'magical': <gensim.models.keyedvectors.Vocab at 0x7efd1349b050>,
#  'preparation': <gensim.models.keyedvectors.Vocab at 0x7efd1349b2d0>,
#  'ruth': <gensim.models.keyedvectors.Vocab at 0x7efd1349b210>,
#  'father': <gensim.models.keyedvectors.Vocab at 0x7efd1349b150>,
#  'haruki': <gensim.models.keyedvectors.Vocab at 0x7efd1349b110>,
#  'deus': <gensim.models.keyedvectors.Vocab at 0x7efd1349b4d0>,
#  'machina': <gensim.models.keyedvectors.Vocab at 0x7efd1349b250>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x7efd1349b450>,
#  'jiko': <gensim.models.keyedvectors.Vocab at 0x7efd1349b1d0>,
#  'discussion': <gensim.models.keyedvectors.Vocab at 0x7efd1349b3d0>,
#  'oliver': <gensim.models.keyedvectors.Vocab at 0x7efd1349b350>,
#  'reminds': <gensim.models.keyedvectors.Vocab at 0x7efd1349b410>,
#  'passed': <gensim.models.keyedvectors.Vocab at 0x7efd1349b310>,
#  'present': <gensim.models.keyedvectors.Vocab at 0x7efd1349b6d0>,
#  'statement': <gensim.models.keyedvectors.Vocab at 0x7efd1349b650>,
#  'involving': <gensim.models.keyedvectors.Vocab at 0x7efd1349b550>,
#  'apparent': <gensim.models.keyedvectors.Vocab at 0x7efd1349b510>,
#  'contradiction': <gensim.models.keyedvectors.Vocab at 0x7efd1349b610>,
#  'equally': <gensim.models.keyedvectors.Vocab at 0x7efd1349b8d0>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x7efd1349b850>,
#  'flow': <gensim.models.keyedvectors.Vocab at 0x7efd1349b5d0>,
#  'background': <gensim.models.keyedvectors.Vocab at 0x7efd1349b810>,
#  'disappearance': <gensim.models.keyedvectors.Vocab at 0x7efd1349b7d0>,
#  'contrived': <gensim.models.keyedvectors.Vocab at 0x7efd1349b750>,
#  'realize': <gensim.models.keyedvectors.Vocab at 0x7efd1349b710>,
#  'stretch': <gensim.models.keyedvectors.Vocab at 0x7efd1349ba50>,
#  'daughter': <gensim.models.keyedvectors.Vocab at 0x7efd1349ba10>,
#  'perished': <gensim.models.keyedvectors.Vocab at 0x7efd1349bad0>,
#  'tsunami': <gensim.models.keyedvectors.Vocab at 0x7efd1349b9d0>,
#  'possibility': <gensim.models.keyedvectors.Vocab at 0x7efd1349b950>,
#  'calling': <gensim.models.keyedvectors.Vocab at 0x7efd1349b910>,
#  'ironic': <gensim.models.keyedvectors.Vocab at 0x7efd1349bcd0>,
#  'question': <gensim.models.keyedvectors.Vocab at 0x7efd1349bc50>,
#  'intervention': <gensim.models.keyedvectors.Vocab at 0x7efd1349bc10>,
#  'suicide': <gensim.models.keyedvectors.Vocab at 0x7efd1349bbd0>,
#  'lydia': <gensim.models.keyedvectors.Vocab at 0x7efd1349bb10>,
#  'alice': <gensim.models.keyedvectors.Vocab at 0x7efd1349bf10>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x7efd1349bb50>,
#  'abrupt': <gensim.models.keyedvectors.Vocab at 0x7efd1349be90>,
#  'adequately': <gensim.models.keyedvectors.Vocab at 0x7efd1349be50>,
#  'motivated': <gensim.models.keyedvectors.Vocab at 0x7efd1349be10>,
#  'woman': <gensim.models.keyedvectors.Vocab at 0x7efd1349bd90>,
#  'forced': <gensim.models.keyedvectors.Vocab at 0x7efd1349bd50>,
#  'marry': <gensim.models.keyedvectors.Vocab at 0x7efd1349bf90>,
#  'orchard': <gensim.models.keyedvectors.Vocab at 0x7efd1349bf50>,
#  'forever': <gensim.models.keyedvectors.Vocab at 0x7efd1349e150>,
#  'fall': <gensim.models.keyedvectors.Vocab at 0x7efd1349e0d0>,
#  'deeply': <gensim.models.keyedvectors.Vocab at 0x7efd1349e090>,
#  'calypso': <gensim.models.keyedvectors.Vocab at 0x7efd1349e050>,
#  'expect': <gensim.models.keyedvectors.Vocab at 0x7efd1349e350>,
#  'supernatural': <gensim.models.keyedvectors.Vocab at 0x7efd1349e2d0>,
#  'originally': <gensim.models.keyedvectors.Vocab at 0x7efd1349e290>,
#  'horror': <gensim.models.keyedvectors.Vocab at 0x7efd1349e250>,
#  'title': <gensim.models.keyedvectors.Vocab at 0x7efd1349e1d0>,
#  'synopsis': <gensim.models.keyedvectors.Vocab at 0x7efd1349e4d0>,
#  'cover': <gensim.models.keyedvectors.Vocab at 0x7efd1349e190>,
#  'suggest': <gensim.models.keyedvectors.Vocab at 0x7efd1349e490>,
#  'jacob': <gensim.models.keyedvectors.Vocab at 0x7efd1349e450>,
#  'discovers': <gensim.models.keyedvectors.Vocab at 0x7efd1349e550>,
#  'loop': <gensim.models.keyedvectors.Vocab at 0x7efd1349e3d0>,
#  'honestly': <gensim.models.keyedvectors.Vocab at 0x7efd1349e390>,
#  'narnia': <gensim.models.keyedvectors.Vocab at 0x7efd1349e750>,
#  'deflated': <gensim.models.keyedvectors.Vocab at 0x7efd1349e6d0>,
#  'disappointed': <gensim.models.keyedvectors.Vocab at 0x7efd1349e690>,
#  'admit': <gensim.models.keyedvectors.Vocab at 0x7efd1349e5d0>,
#  'suck': <gensim.models.keyedvectors.Vocab at 0x7efd1349e590>,
#  'watching': <gensim.models.keyedvectors.Vocab at 0x7efd1349e950>,
#  'crush': <gensim.models.keyedvectors.Vocab at 0x7efd1349e8d0>,
#  'constantly': <gensim.models.keyedvectors.Vocab at 0x7efd1349e650>,
#  'kiss': <gensim.models.keyedvectors.Vocab at 0x7efd1349e890>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x7efd1349e850>,
#  'initially': <gensim.models.keyedvectors.Vocab at 0x7efd1349e7d0>,
#  'biracial': <gensim.models.keyedvectors.Vocab at 0x7efd1349e790>,
#  'savior': <gensim.models.keyedvectors.Vocab at 0x7efd1349eb90>,
#  'rescue': <gensim.models.keyedvectors.Vocab at 0x7efd1349eb10>,
#  'poor': <gensim.models.keyedvectors.Vocab at 0x7efd1349ea90>,
#  'movie': <gensim.models.keyedvectors.Vocab at 0x7efd1349ead0>,
#  'pretty': <gensim.models.keyedvectors.Vocab at 0x7efd1349e9d0>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7efd1349ea10>,
#  'explaining': <gensim.models.keyedvectors.Vocab at 0x7efd1349ed90>,
#  'adele': <gensim.models.keyedvectors.Vocab at 0x7efd1349ed10>,
#  'clementine': <gensim.models.keyedvectors.Vocab at 0x7efd1349ecd0>,
#  'cheating': <gensim.models.keyedvectors.Vocab at 0x7efd1349ec90>,
#  'abercrombie': <gensim.models.keyedvectors.Vocab at 0x7efd1349ec10>,
#  'miss': <gensim.models.keyedvectors.Vocab at 0x7efd1349ebd0>,
#  'wren': <gensim.models.keyedvectors.Vocab at 0x7efd1349ef90>,
#  'fucking': <gensim.models.keyedvectors.Vocab at 0x7efd1349ef10>,
#  'stupid': <gensim.models.keyedvectors.Vocab at 0x7efd1349eed0>,
#  'seriously': <gensim.models.keyedvectors.Vocab at 0x7efd1349ee90>,
#  'trusted': <gensim.models.keyedvectors.Vocab at 0x7efd1349ee10>,
#  'asshat': <gensim.models.keyedvectors.Vocab at 0x7efd1349edd0>,
#  'kidding': <gensim.models.keyedvectors.Vocab at 0x7efd1349efd0>,
#  'unrealistic': <gensim.models.keyedvectors.Vocab at 0x7efd134a11d0>,
#  'fuck': <gensim.models.keyedvectors.Vocab at 0x7efd134a1150>,
#  'brownwyn': <gensim.models.keyedvectors.Vocab at 0x7efd134a10d0>,
#  'forgot': <gensim.models.keyedvectors.Vocab at 0x7efd134a13d0>,
#  'spell': <gensim.models.keyedvectors.Vocab at 0x7efd134a1350>,
#  'hold': <gensim.models.keyedvectors.Vocab at 0x7efd134a1050>,
#  'emma': <gensim.models.keyedvectors.Vocab at 0x7efd134a1110>,
#  'caul': <gensim.models.keyedvectors.Vocab at 0x7efd134a1310>,
#  'althea': <gensim.models.keyedvectors.Vocab at 0x7efd134a12d0>,
#  'extraordinary': <gensim.models.keyedvectors.Vocab at 0x7efd134a1250>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x7efd134a1210>,
#  'correlate': <gensim.models.keyedvectors.Vocab at 0x7efd134a15d0>,
#  'develop': <gensim.models.keyedvectors.Vocab at 0x7efd134a1550>,
#  'brought': <gensim.models.keyedvectors.Vocab at 0x7efd134a1510>,
#  'definitely': <gensim.models.keyedvectors.Vocab at 0x7efd134a1450>,
#  'picked': <gensim.models.keyedvectors.Vocab at 0x7efd134a1410>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x7efd134a17d0>,
#  'dante': <gensim.models.keyedvectors.Vocab at 0x7efd134a1750>,
#  'beat': <gensim.models.keyedvectors.Vocab at 0x7efd134a14d0>,
#  'lose': <gensim.models.keyedvectors.Vocab at 0x7efd134a1710>,
#  'compassion': <gensim.models.keyedvectors.Vocab at 0x7efd134a16d0>,
#  'drunk': <gensim.models.keyedvectors.Vocab at 0x7efd134a1650>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x7efd134a19d0>,
#  'raped': <gensim.models.keyedvectors.Vocab at 0x7efd134a1950>,
#  'knew': <gensim.models.keyedvectors.Vocab at 0x7efd134a1610>,
#  'seth': <gensim.models.keyedvectors.Vocab at 0x7efd134a1910>,
#  'annoying': <gensim.models.keyedvectors.Vocab at 0x7efd134a1850>,
#  'wrote': <gensim.models.keyedvectors.Vocab at 0x7efd134a1810>,
#  'lord': <gensim.models.keyedvectors.Vocab at 0x7efd134a1bd0>,
#  'aidan': <gensim.models.keyedvectors.Vocab at 0x7efd134a1b50>,
#  'hate': <gensim.models.keyedvectors.Vocab at 0x7efd134a18d0>,
#  'putting': <gensim.models.keyedvectors.Vocab at 0x7efd134a1b10>,
#  'alex': <gensim.models.keyedvectors.Vocab at 0x7efd134a1a50>,
#  'elixir': <gensim.models.keyedvectors.Vocab at 0x7efd134a1a10>,
#  'punishes': <gensim.models.keyedvectors.Vocab at 0x7efd134a1ad0>,
#  'avoiding': <gensim.models.keyedvectors.Vocab at 0x7efd134a1dd0>,
#  'dimitri': <gensim.models.keyedvectors.Vocab at 0x7efd134a1d50>,
#  'rose': <gensim.models.keyedvectors.Vocab at 0x7efd134a1d10>,
#  'strigoi': <gensim.models.keyedvectors.Vocab at 0x7efd134a1cd0>,
#  'predicted': <gensim.models.keyedvectors.Vocab at 0x7efd134a1c10>,
#  'turn': <gensim.models.keyedvectors.Vocab at 0x7efd134a1fd0>,
#  'hungry': <gensim.models.keyedvectors.Vocab at 0x7efd134a1f50>,
#  'leon': <gensim.models.keyedvectors.Vocab at 0x7efd134a1c50>,
#  'apollo': <gensim.models.keyedvectors.Vocab at 0x7efd134a1ed0>,
#  'addie': <gensim.models.keyedvectors.Vocab at 0x7efd134a1f10>,
#  'slowing': <gensim.models.keyedvectors.Vocab at 0x7efd134a1e50>,
#  'ability': <gensim.models.keyedvectors.Vocab at 0x7efd134a1e10>,
#  'guess': <gensim.models.keyedvectors.Vocab at 0x7efd134a2210>,
#  'advance': <gensim.models.keyedvectors.Vocab at 0x7efd134a2190>,
#  'plot': <gensim.models.keyedvectors.Vocab at 0x7efd134a2150>,
#  'justin': <gensim.models.keyedvectors.Vocab at 0x7efd134a2110>,
#  'development': <gensim.models.keyedvectors.Vocab at 0x7efd134a2050>,
#  'rape': <gensim.models.keyedvectors.Vocab at 0x7efd134a2410>,
#  'certain': <gensim.models.keyedvectors.Vocab at 0x7efd134a2390>,
#  'surprise': <gensim.models.keyedvectors.Vocab at 0x7efd134a2350>,
#  'extremely': <gensim.models.keyedvectors.Vocab at 0x7efd134a2090>,
#  'irresistible': <gensim.models.keyedvectors.Vocab at 0x7efd134a2310>,
#  'vampire': <gensim.models.keyedvectors.Vocab at 0x7efd134a2290>,
#  'anti': <gensim.models.keyedvectors.Vocab at 0x7efd134a2250>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x7efd134a2610>,
#  'greater': <gensim.models.keyedvectors.Vocab at 0x7efd134a2590>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x7efd134a2510>,
#  'mysteriously': <gensim.models.keyedvectors.Vocab at 0x7efd134a2450>,
#  'drawn': <gensim.models.keyedvectors.Vocab at 0x7efd134a2550>,
#  'stuttering': <gensim.models.keyedvectors.Vocab at 0x7efd134a2810>,
#  'horny': <gensim.models.keyedvectors.Vocab at 0x7efd134a2790>,
#  'blushing': <gensim.models.keyedvectors.Vocab at 0x7efd134a2750>,
#  'fool': <gensim.models.keyedvectors.Vocab at 0x7efd134a2490>,
#  'sigh': <gensim.models.keyedvectors.Vocab at 0x7efd134a2710>,
#  'dangerous': <gensim.models.keyedvectors.Vocab at 0x7efd134a2690>,
#  'warns': <gensim.models.keyedvectors.Vocab at 0x7efd134a2650>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x7efd134a2990>,
#  'attracted': <gensim.models.keyedvectors.Vocab at 0x7efd134a2950>,
#  'blah': <gensim.models.keyedvectors.Vocab at 0x7efd134a2a10>,
#  'complication': <gensim.models.keyedvectors.Vocab at 0x7efd134a2910>,
#  'breakup': <gensim.models.keyedvectors.Vocab at 0x7efd134a2850>,
#  'repeat': <gensim.models.keyedvectors.Vocab at 0x7efd134a2c50>,
#  'idiot': <gensim.models.keyedvectors.Vocab at 0x7efd134a2bd0>,
#  'cook': <gensim.models.keyedvectors.Vocab at 0x7efd134a2b90>,
#  'twilight': <gensim.models.keyedvectors.Vocab at 0x7efd134a2890>,
#  'obviously': <gensim.models.keyedvectors.Vocab at 0x7efd134a2b50>,
#  'michael': <gensim.models.keyedvectors.Vocab at 0x7efd134a2ad0>,
#  'sheesh': <gensim.models.keyedvectors.Vocab at 0x7efd134a2e50>,
#  'holly': <gensim.models.keyedvectors.Vocab at 0x7efd134a2dd0>,
#  'japek': <gensim.models.keyedvectors.Vocab at 0x7efd134a2a90>,
#  'instance': <gensim.models.keyedvectors.Vocab at 0x7efd134a2d90>,
#  'explanation': <gensim.models.keyedvectors.Vocab at 0x7efd134a2d50>,
#  'convenient': <gensim.models.keyedvectors.Vocab at 0x7efd134a2c90>,
#  'cameron': <gensim.models.keyedvectors.Vocab at 0x7efd134a2fd0>,
#  'childhood': <gensim.models.keyedvectors.Vocab at 0x7efd134a2f90>,
#  'swimmer': <gensim.models.keyedvectors.Vocab at 0x7efd134a2f50>,
#  'lesbian': <gensim.models.keyedvectors.Vocab at 0x7efd134a2cd0>,
#  'amazes': <gensim.models.keyedvectors.Vocab at 0x7efd134a2ed0>,
#  'ilse': <gensim.models.keyedvectors.Vocab at 0x7efd134a2e90>,
#  'practically': <gensim.models.keyedvectors.Vocab at 0x7efd134a6090>,
#  'gerda': <gensim.models.keyedvectors.Vocab at 0x7efd134a6290>,
#  'raspberry': <gensim.models.keyedvectors.Vocab at 0x7efd134a6210>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x7efd134a61d0>,
#  'eating': <gensim.models.keyedvectors.Vocab at 0x7efd134a6190>,
#  'gave': <gensim.models.keyedvectors.Vocab at 0x7efd134a60d0>,
#  'frau': <gensim.models.keyedvectors.Vocab at 0x7efd134a6490>,
#  'kugler': <gensim.models.keyedvectors.Vocab at 0x7efd134a63d0>,
#  'amazing': <gensim.models.keyedvectors.Vocab at 0x7efd134a6110>,
#  'confused': <gensim.models.keyedvectors.Vocab at 0x7efd134a6390>,
#  'correct': <gensim.models.keyedvectors.Vocab at 0x7efd134a6310>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x7efd134a6410>,
#  'murder': <gensim.models.keyedvectors.Vocab at 0x7efd134a62d0>,
#  'marston': <gensim.models.keyedvectors.Vocab at 0x7efd134a6690>,
#  'killer': <gensim.models.keyedvectors.Vocab at 0x7efd134a6610>,
#  'pretend': <gensim.models.keyedvectors.Vocab at 0x7efd134a65d0>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x7efd134a6590>,
#  'suspicion': <gensim.models.keyedvectors.Vocab at 0x7efd134a6510>,
#  'broke': <gensim.models.keyedvectors.Vocab at 0x7efd134a6890>,
#  'secret': <gensim.models.keyedvectors.Vocab at 0x7efd134a67d0>,
#  'peyton': <gensim.models.keyedvectors.Vocab at 0x7efd134a6790>,
#  'jace': <gensim.models.keyedvectors.Vocab at 0x7efd134a64d0>,
#  'prepare': <gensim.models.keyedvectors.Vocab at 0x7efd134a6710>,
#  'ranting': <gensim.models.keyedvectors.Vocab at 0x7efd134a6810>,
#  'contain': <gensim.models.keyedvectors.Vocab at 0x7efd134a66d0>,
#  'parent': <gensim.models.keyedvectors.Vocab at 0x7efd134a6a90>,
#  'divorce': <gensim.models.keyedvectors.Vocab at 0x7efd134a6a10>,
#  'considering': <gensim.models.keyedvectors.Vocab at 0x7efd134a69d0>,
#  'date': <gensim.models.keyedvectors.Vocab at 0x7efd134a6990>,
#  'wonder': <gensim.models.keyedvectors.Vocab at 0x7efd134a6910>,
#  'stole': <gensim.models.keyedvectors.Vocab at 0x7efd134a6c90>,
#  'camille': <gensim.models.keyedvectors.Vocab at 0x7efd134a6bd0>,
#  'sensible': <gensim.models.keyedvectors.Vocab at 0x7efd134a6b90>,
#  'sleep': <gensim.models.keyedvectors.Vocab at 0x7efd134a68d0>,
#  'john': <gensim.models.keyedvectors.Vocab at 0x7efd134a6b10>,
#  'creepy': <gensim.models.keyedvectors.Vocab at 0x7efd134a6c10>,
#  'anyways': <gensim.models.keyedvectors.Vocab at 0x7efd134a6ad0>,
#  'intrigue': <gensim.models.keyedvectors.Vocab at 0x7efd134a6e90>,
# ...
#  'curious': <gensim.models.keyedvectors.Vocab at 0x7efd134aad50>,
#  'started': <gensim.models.keyedvectors.Vocab at 0x7efd134aacd0>,
#  'running': <gensim.models.keyedvectors.Vocab at 0x7efd134aac90>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x7efd134aa990>,
#  'cami': <gensim.models.keyedvectors.Vocab at 0x7efd134aabd0>,
#  'feeling': <gensim.models.keyedvectors.Vocab at 0x7efd134aab90>,
#  'slow': <gensim.models.keyedvectors.Vocab at 0x7efd134aaf50>,
#  'beginning': <gensim.models.keyedvectors.Vocab at 0x7efd134aac50>,
#  'middle': <gensim.models.keyedvectors.Vocab at 0x7efd134aaed0>,
#  'sweet': <gensim.models.keyedvectors.Vocab at 0x7efd134aae90>,
#  'sickly': <gensim.models.keyedvectors.Vocab at 0x7efd134aae50>,
#  'basically': <gensim.models.keyedvectors.Vocab at 0x7efd134aadd0>,
#  'necrophilia': <gensim.models.keyedvectors.Vocab at 0x7efd134aafd0>,
#  'dimensional': <gensim.models.keyedvectors.Vocab at 0x7efd134aaf90>,
#  'sympathy': <gensim.models.keyedvectors.Vocab at 0x7efd134aad90>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x7efd134ae110>,
#  'twist': <gensim.models.keyedvectors.Vocab at 0x7efd134ae0d0>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x7efd134ae090>,
#  'jase': <gensim.models.keyedvectors.Vocab at 0x7efd134ae390>,
#  'finished': <gensim.models.keyedvectors.Vocab at 0x7efd134ae190>,
#  'looked': <gensim.models.keyedvectors.Vocab at 0x7efd134ae310>,
#  'naive': <gensim.models.keyedvectors.Vocab at 0x7efd134ae2d0>,
#  'dense': <gensim.models.keyedvectors.Vocab at 0x7efd134ae290>,
#  'literally': <gensim.models.keyedvectors.Vocab at 0x7efd134ae210>,
#  'raising': <gensim.models.keyedvectors.Vocab at 0x7efd134ae590>,
#  'voice': <gensim.models.keyedvectors.Vocab at 0x7efd134ae510>,
#  'saved': <gensim.models.keyedvectors.Vocab at 0x7efd134ae4d0>,
#  'killing': <gensim.models.keyedvectors.Vocab at 0x7efd134ae1d0>,
#  'loomis': <gensim.models.keyedvectors.Vocab at 0x7efd134ae410>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x7efd134ae3d0>,
#  'faro': <gensim.models.keyedvectors.Vocab at 0x7efd134ae790>,
#  'tracking': <gensim.models.keyedvectors.Vocab at 0x7efd134ae490>,
#  'cave': <gensim.models.keyedvectors.Vocab at 0x7efd134ae710>,
#  'realized': <gensim.models.keyedvectors.Vocab at 0x7efd134ae6d0>,
#  'hell': <gensim.models.keyedvectors.Vocab at 0x7efd134ae690>,
#  'extreme': <gensim.models.keyedvectors.Vocab at 0x7efd134ae610>,
#  'melodramatic': <gensim.models.keyedvectors.Vocab at 0x7efd134ae990>,
#  'shaking': <gensim.models.keyedvectors.Vocab at 0x7efd134ae910>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7efd134ae8d0>,
#  'adorable': <gensim.models.keyedvectors.Vocab at 0x7efd134ae5d0>,
#  'nagging': <gensim.models.keyedvectors.Vocab at 0x7efd134ae810>,
#  'slut': <gensim.models.keyedvectors.Vocab at 0x7efd134ae7d0>,
#  'shaming': <gensim.models.keyedvectors.Vocab at 0x7efd134aeb90>,
#  'equal': <gensim.models.keyedvectors.Vocab at 0x7efd134ae890>,
#  'gabriel': <gensim.models.keyedvectors.Vocab at 0x7efd134aeb10>,
#  'cecily': <gensim.models.keyedvectors.Vocab at 0x7efd134aead0>,
#  'couple': <gensim.models.keyedvectors.Vocab at 0x7efd134aea90>,
#  'tessa': <gensim.models.keyedvectors.Vocab at 0x7efd134aea10>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x7efd134aed90>,
#  'technically': <gensim.models.keyedvectors.Vocab at 0x7efd134aed10>,
#  'page': <gensim.models.keyedvectors.Vocab at 0x7efd134aecd0>,
#  'madrigal': <gensim.models.keyedvectors.Vocab at 0x7efd134ae9d0>,
#  'wishbone': <gensim.models.keyedvectors.Vocab at 0x7efd134aec10>,
#  'situation': <gensim.models.keyedvectors.Vocab at 0x7efd134aebd0>,
#  'introduced': <gensim.models.keyedvectors.Vocab at 0x7efd134aef90>,
#  'karou': <gensim.models.keyedvectors.Vocab at 0x7efd134aec90>,
#  'stone': <gensim.models.keyedvectors.Vocab at 0x7efd134aef10>,
#  'clair': <gensim.models.keyedvectors.Vocab at 0x7efd134aeed0>,
#  'headed': <gensim.models.keyedvectors.Vocab at 0x7efd134aee90>,
#  'dave': <gensim.models.keyedvectors.Vocab at 0x7efd134aee10>,
#  'bridgette': <gensim.models.keyedvectors.Vocab at 0x7efd134aefd0>,
#  'annoy': <gensim.models.keyedvectors.Vocab at 0x7efd134aedd0>,
#  'todd': <gensim.models.keyedvectors.Vocab at 0x7efd134af1d0>,
#  'hewitt': <gensim.models.keyedvectors.Vocab at 0x7efd134af110>,
#  'prof': <gensim.models.keyedvectors.Vocab at 0x7efd134af0d0>,
#  'travel': <gensim.models.keyedvectors.Vocab at 0x7efd134af050>,
#  'friendship': <gensim.models.keyedvectors.Vocab at 0x7efd134af3d0>,
#  'dynamic': <gensim.models.keyedvectors.Vocab at 0x7efd134af150>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x7efd134af350>,
#  'exactly': <gensim.models.keyedvectors.Vocab at 0x7efd134af310>,
#  'original': <gensim.models.keyedvectors.Vocab at 0x7efd134af2d0>,
#  'dropping': <gensim.models.keyedvectors.Vocab at 0x7efd134af250>,
#  'cheated': <gensim.models.keyedvectors.Vocab at 0x7efd134af5d0>,
#  'damn': <gensim.models.keyedvectors.Vocab at 0x7efd134af550>,
#  'immensely': <gensim.models.keyedvectors.Vocab at 0x7efd134af510>,
#  'developed': <gensim.models.keyedvectors.Vocab at 0x7efd134af210>,
#  'wanting': <gensim.models.keyedvectors.Vocab at 0x7efd134af450>,
#  'anymore': <gensim.models.keyedvectors.Vocab at 0x7efd134af410>,
#  'betrayed': <gensim.models.keyedvectors.Vocab at 0x7efd134af7d0>,
#  'simon': <gensim.models.keyedvectors.Vocab at 0x7efd134af4d0>,
#  'isabelle': <gensim.models.keyedvectors.Vocab at 0x7efd134af750>,
#  'dating': <gensim.models.keyedvectors.Vocab at 0x7efd134af710>,
#  'confusion': <gensim.models.keyedvectors.Vocab at 0x7efd134af6d0>,
#  'zone': <gensim.models.keyedvectors.Vocab at 0x7efd134af650>,
#  'boyfriend': <gensim.models.keyedvectors.Vocab at 0x7efd134af9d0>,
#  'girlfriend': <gensim.models.keyedvectors.Vocab at 0x7efd134af950>,
#  'shared': <gensim.models.keyedvectors.Vocab at 0x7efd134af910>,
#  'bright': <gensim.models.keyedvectors.Vocab at 0x7efd134af610>,
#  'figure': <gensim.models.keyedvectors.Vocab at 0x7efd134af850>,
#  'matter': <gensim.models.keyedvectors.Vocab at 0x7efd134af810>,
#  'saving': <gensim.models.keyedvectors.Vocab at 0x7efd134afbd0>,
#  'grace': <gensim.models.keyedvectors.Vocab at 0x7efd134af8d0>,
#  'bloodline': <gensim.models.keyedvectors.Vocab at 0x7efd134afb50>,
#  'strange': <gensim.models.keyedvectors.Vocab at 0x7efd134afb10>,
#  'madison': <gensim.models.keyedvectors.Vocab at 0x7efd134afad0>,
#  'claim': <gensim.models.keyedvectors.Vocab at 0x7efd134afa50>,
#  'stolen': <gensim.models.keyedvectors.Vocab at 0x7efd134afdd0>,
#  'diamond': <gensim.models.keyedvectors.Vocab at 0x7efd134afd50>,
#  'steal': <gensim.models.keyedvectors.Vocab at 0x7efd134afd10>,
#  'lied': <gensim.models.keyedvectors.Vocab at 0x7efd134afa10>,
#  'credit': <gensim.models.keyedvectors.Vocab at 0x7efd134afc50>,
#  'fame': <gensim.models.keyedvectors.Vocab at 0x7efd134afc10>,
#  'mainly': <gensim.models.keyedvectors.Vocab at 0x7efd134affd0>,
#  'xander': <gensim.models.keyedvectors.Vocab at 0x7efd134afcd0>,
#  'murry': <gensim.models.keyedvectors.Vocab at 0x7efd134aff50>,
#  'heroine': <gensim.models.keyedvectors.Vocab at 0x7efd134aff10>,
#  'needed': <gensim.models.keyedvectors.Vocab at 0x7efd134afed0>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x7efd134afe50>,
#  'ultimately': <gensim.models.keyedvectors.Vocab at 0x7efd134afe10>,
#  'defeat': <gensim.models.keyedvectors.Vocab at 0x7efd134b1210>,
#  'volcano': <gensim.models.keyedvectors.Vocab at 0x7efd134b1190>,
#  'super': <gensim.models.keyedvectors.Vocab at 0x7efd134b1110>,
#  'rage': <gensim.models.keyedvectors.Vocab at 0x7efd134b1090>,
#  'beneath': <gensim.models.keyedvectors.Vocab at 0x7efd134b1050>,
#  'surface': <gensim.models.keyedvectors.Vocab at 0x7efd134b1410>,
#  'engle': <gensim.models.keyedvectors.Vocab at 0x7efd134b1150>,
#  'crazy': <gensim.models.keyedvectors.Vocab at 0x7efd134b1390>,
#  'snowflake': <gensim.models.keyedvectors.Vocab at 0x7efd134b1350>,
#  'beck': <gensim.models.keyedvectors.Vocab at 0x7efd134b1310>,
#  'assume': <gensim.models.keyedvectors.Vocab at 0x7efd134b1290>,
#  'deliver': <gensim.models.keyedvectors.Vocab at 0x7efd134b1610>,
#  'typical': <gensim.models.keyedvectors.Vocab at 0x7efd134b1590>,
#  'enter': <gensim.models.keyedvectors.Vocab at 0x7efd134b1550>,
#  'anxiety': <gensim.models.keyedvectors.Vocab at 0x7efd134b1250>,
#  'disorder': <gensim.models.keyedvectors.Vocab at 0x7efd134b1490>,
#  'portion': <gensim.models.keyedvectors.Vocab at 0x7efd134b1450>,
#  'risky': <gensim.models.keyedvectors.Vocab at 0x7efd134b1810>,
#  'haydu': <gensim.models.keyedvectors.Vocab at 0x7efd134b1510>,
#  'pull': <gensim.models.keyedvectors.Vocab at 0x7efd134b1790>,
#  'creating': <gensim.models.keyedvectors.Vocab at 0x7efd134b1750>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x7efd134b1710>,
#  'believed': <gensim.models.keyedvectors.Vocab at 0x7efd134b1690>,
#  'explored': <gensim.models.keyedvectors.Vocab at 0x7efd134b1a10>,
#  'truly': <gensim.models.keyedvectors.Vocab at 0x7efd134b1990>,
#  'expected': <gensim.models.keyedvectors.Vocab at 0x7efd134b1650>,
#  'explores': <gensim.models.keyedvectors.Vocab at 0x7efd134b1910>,
#  'compulsion': <gensim.models.keyedvectors.Vocab at 0x7efd134b1890>,
#  'reader': <gensim.models.keyedvectors.Vocab at 0x7efd134b1850>,
#  'uncomfortable': <gensim.models.keyedvectors.Vocab at 0x7efd134b1c10>,
#  'allow': <gensim.models.keyedvectors.Vocab at 0x7efd134b1950>,
#  'exploration': <gensim.models.keyedvectors.Vocab at 0x7efd134b1b90>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x7efd134b1b50>,
#  'asking': <gensim.models.keyedvectors.Vocab at 0x7efd134b1a90>,
#  'worrying': <gensim.models.keyedvectors.Vocab at 0x7efd134b1a50>,
#  'offer': <gensim.models.keyedvectors.Vocab at 0x7efd134b1e10>,
#  'realistic': <gensim.models.keyedvectors.Vocab at 0x7efd134b1d90>,
#  'answer': <gensim.models.keyedvectors.Vocab at 0x7efd134b1b10>,
#  'delivers': <gensim.models.keyedvectors.Vocab at 0x7efd134b1d10>,
#  'multiple': <gensim.models.keyedvectors.Vocab at 0x7efd134b1c90>,
#  'depiction': <gensim.models.keyedvectors.Vocab at 0x7efd134b1c50>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7efd134b1f90>,
#  'sufferer': <gensim.models.keyedvectors.Vocab at 0x7efd134b1d50>,
#  'view': <gensim.models.keyedvectors.Vocab at 0x7efd134b1f50>,
#  'compassionate': <gensim.models.keyedvectors.Vocab at 0x7efd134b1f10>,
#  'battled': <gensim.models.keyedvectors.Vocab at 0x7efd134b1e50>,
#  'giving': <gensim.models.keyedvectors.Vocab at 0x7efd134b1e90>,
#  'austin': <gensim.models.keyedvectors.Vocab at 0x7efd1350b6d0>,
#  'action': <gensim.models.keyedvectors.Vocab at 0x7efd1350b3d0>,
#  'sleeping': <gensim.models.keyedvectors.Vocab at 0x7efd1350b310>,
#  'overnight': <gensim.models.keyedvectors.Vocab at 0x7efd1350bad0>,
#  'clue': <gensim.models.keyedvectors.Vocab at 0x7efd1350b510>,
#  'piece': <gensim.models.keyedvectors.Vocab at 0x7efd1350be50>,
#  'vision': <gensim.models.keyedvectors.Vocab at 0x7efd1350b850>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x7efd1350b450>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x7efd1350b910>,
#  'lgbtqa': <gensim.models.keyedvectors.Vocab at 0x7efd1350bb50>,
#  'series': <gensim.models.keyedvectors.Vocab at 0x7efd1350bd10>,
#  'dramatic': <gensim.models.keyedvectors.Vocab at 0x7efd1350b5d0>,
#  'effect': <gensim.models.keyedvectors.Vocab at 0x7efd1350b410>,
#  'death': <gensim.models.keyedvectors.Vocab at 0x7efd1350bf10>,
#  'usually': <gensim.models.keyedvectors.Vocab at 0x7efd1350bc10>,
#  'excited': <gensim.models.keyedvectors.Vocab at 0x7efd1350b7d0>,
#  'diversity': <gensim.models.keyedvectors.Vocab at 0x7efd1350b810>,
#  'tale': <gensim.models.keyedvectors.Vocab at 0x7efd1350ba50>,
#  'lover': <gensim.models.keyedvectors.Vocab at 0x7efd1350bd50>,
#  'motif': <gensim.models.keyedvectors.Vocab at 0x7efd1350b350>,
#  'fail': <gensim.models.keyedvectors.Vocab at 0x7efd1350b2d0>,
#  'listen': <gensim.models.keyedvectors.Vocab at 0x7efd1350bcd0>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x7efd1350ba10>,
#  'came': <gensim.models.keyedvectors.Vocab at 0x7efd1350b750>,
#  'england': <gensim.models.keyedvectors.Vocab at 0x7efd1350b9d0>,
#  'treat': <gensim.models.keyedvectors.Vocab at 0x7efd1350b950>,
#  'marriage': <gensim.models.keyedvectors.Vocab at 0x7efd1350b0d0>,
#  'menu': <gensim.models.keyedvectors.Vocab at 0x7efd1350bbd0>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x7efd1350bb10>,
#  'helplessly': <gensim.models.keyedvectors.Vocab at 0x7efd1350bed0>,
#  'inevitably': <gensim.models.keyedvectors.Vocab at 0x7efd1350be10>,
#  'rock': <gensim.models.keyedvectors.Vocab at 0x7efd1350bdd0>,
#  'thesis': <gensim.models.keyedvectors.Vocab at 0x7efd1350bfd0>,
#  'agriculture': <gensim.models.keyedvectors.Vocab at 0x7efd1350b710>,
#  'entirely': <gensim.models.keyedvectors.Vocab at 0x7efd1350b550>,
#  'form': <gensim.models.keyedvectors.Vocab at 0x7efd1350bc50>,
#  'arose': <gensim.models.keyedvectors.Vocab at 0x7efd1350b8d0>,
#  'taker': <gensim.models.keyedvectors.Vocab at 0x7efd1350b650>,
#  'seek': <gensim.models.keyedvectors.Vocab at 0x7efd1350b4d0>,
#  'destiny': <gensim.models.keyedvectors.Vocab at 0x7efd1350b050>,
#  'relaxing': <gensim.models.keyedvectors.Vocab at 0x7efd1350b150>,
#  'enjoying': <gensim.models.keyedvectors.Vocab at 0x7efd1350b210>,
#  'fruit': <gensim.models.keyedvectors.Vocab at 0x7efd1350b1d0>,
#  'garden': <gensim.models.keyedvectors.Vocab at 0x7efd1350b250>,
#  'ticked': <gensim.models.keyedvectors.Vocab at 0x7efd1350bf50>,
#  'resolution': <gensim.models.keyedvectors.Vocab at 0x7efd1350b610>,
#  'cliffhanger': <gensim.models.keyedvectors.Vocab at 0x7efd1350b110>,
#  'cohesive': <gensim.models.keyedvectors.Vocab at 0x7efd134ff210>,
#  'satisfaction': <gensim.models.keyedvectors.Vocab at 0x7efd134ffd90>,
#  'custom': <gensim.models.keyedvectors.Vocab at 0x7efd134ff810>,
#  'potential': <gensim.models.keyedvectors.Vocab at 0x7efd134ffa50>,
#  'immense': <gensim.models.keyedvectors.Vocab at 0x7efd134ff090>,
#  'choppy': <gensim.models.keyedvectors.Vocab at 0x7efd134ff310>,
#  'rough': <gensim.models.keyedvectors.Vocab at 0x7efd134ff250>,
#  'reworked': <gensim.models.keyedvectors.Vocab at 0x7efd134ff550>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7efd134ffd10>,
#  'overall': <gensim.models.keyedvectors.Vocab at 0x7efd134ff890>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x7efd134fff90>,
#  'awakening': <gensim.models.keyedvectors.Vocab at 0x7efd134ffe10>,
#  'hybrid': <gensim.models.keyedvectors.Vocab at 0x7efd134ffb90>,
#  'ezra': <gensim.models.keyedvectors.Vocab at 0x7efd134ff390>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x7efd134ff710>,
#  'revolt': <gensim.models.keyedvectors.Vocab at 0x7efd134ffc50>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x7efd134ff510>,
#  'realizing': <gensim.models.keyedvectors.Vocab at 0x7efd134b5050>,
#  'letter': <gensim.models.keyedvectors.Vocab at 0x7efd134b5250>,
#  'uncle': <gensim.models.keyedvectors.Vocab at 0x7efd134b51d0>,
#  'random': <gensim.models.keyedvectors.Vocab at 0x7efd134b5190>,
#  'ridiculous': <gensim.models.keyedvectors.Vocab at 0x7efd134b5150>,
#  'zero': <gensim.models.keyedvectors.Vocab at 0x7efd134b50d0>,
#  'ventclaire': <gensim.models.keyedvectors.Vocab at 0x7efd134b5090>,
#  'lily': <gensim.models.keyedvectors.Vocab at 0x7efd134b5450>,
#  'assumes': <gensim.models.keyedvectors.Vocab at 0x7efd134b53d0>,
#  'boinked': <gensim.models.keyedvectors.Vocab at 0x7efd134b5390>,
#  'rule': <gensim.models.keyedvectors.Vocab at 0x7efd134b5350>,
#  'interact': <gensim.models.keyedvectors.Vocab at 0x7efd134b5290>,
#  'prodigy': <gensim.models.keyedvectors.Vocab at 0x7efd134b5650>,
#  'dominic': <gensim.models.keyedvectors.Vocab at 0x7efd134b55d0>,
#  'mate': <gensim.models.keyedvectors.Vocab at 0x7efd134b5590>,
#  'fantasy': <gensim.models.keyedvectors.Vocab at 0x7efd134b52d0>,
#  'category': <gensim.models.keyedvectors.Vocab at 0x7efd134b5550>,
#  'amazon': <gensim.models.keyedvectors.Vocab at 0x7efd134b54d0>,
#  'defined': <gensim.models.keyedvectors.Vocab at 0x7efd134b5490>,
#  'sookie': <gensim.models.keyedvectors.Vocab at 0x7efd134b5850>,
#  'eric': <gensim.models.keyedvectors.Vocab at 0x7efd134b57d0>,
#  'break': <gensim.models.keyedvectors.Vocab at 0x7efd134b5790>,
#  'accept': <gensim.models.keyedvectors.Vocab at 0x7efd134b5750>,
#  'determined': <gensim.models.keyedvectors.Vocab at 0x7efd134b5690>,
#  ...}

# %%
X = w2v[w2v.wv.vocab]
pca = PCA(n_components=2)

result = pca.fit_transform(X)

# create a scatter plot of the projection
plt.scatter(result[:, 0], result[:, 1])
words = list(w2v.wv.vocab)

listAnchores=[]
for i, word in enumerate(words):
  lstDis=[]
  for j in range(len(words)):
    if i!=j:
      lstDis.append(np.sqrt(np.square(result[i, 0]-result[j, 0])+np.square(result[i, 0]-result[j, 0])))
  minDis= float(min(lstDis))
  if minDis>=0.005:
    listAnchores.append({'word':word,'i':i,'dis':lstDis})

  plt.annotate(word, xy=(result[i, 0], result[i, 1]))

plt.show()

# %%
resDf=pd.DataFrame.from_dict(listAnchores)

# %%
resDf.head()
# Out:
#          word    i                                                dis
# 0       alien   23  [4.8987455, 4.633672, 1.0438783, 1.6577914, 1....
# 1     science  122  [5.0959625, 4.8308897, 1.2410955, 1.8550086, 1...
# 2        live  129  [5.4194145, 5.1543417, 1.5645477, 2.1784606, 2...
# 3       world  154  [5.069519, 4.804446, 1.214652, 1.828565, 1.896...
# 4  separation  285  [6.2519813, 5.9869084, 2.3971145, 3.0110276, 3...

# %%
resDf.to_csv('/content/drive/MyDrive/SpoilerData/out2.csv')

# %%
print(listAnchores[0]['word'])
# Out:
# alien

# %%
plt.scatter(result[:, 0], result[:, 1])
for i in listAnchores:
  plt.annotate(i['word'], xy=(result[i['i'], 0], result[i['i'], 1]))
plt.show()

# %%
print(result)

# %%
print(min(result[:,0]))

# %%
print(result.shape)

# %%
print(lst[0])

# %%
w=newTfIdf.toarray()

# %%
df4=df3[df3['TF-IDF']>0]
df4

# %%
print(len(df4))

# %%
df_review['review_sentences'].index
# Out:
# RangeIndex(start=0, stop=1378033, step=1)

# %%
print(w)

# %%
import tomotopy as tp
mdl = tp.CTModel(k=61)
for i in processed_docs.index:
    mdl.add_doc(processed_docs[i])

# %%
for j in range(0, 100, 10):
    mdl.train(10)
    print('Iteration: {}\tLog-likelihood: {}'.format(j, mdl.ll_per_word))
# Out:
# Iteration: 0	Log-likelihood: -19.905206984608654
# Iteration: 10	Log-likelihood: -25.002633670296323
# Iteration: 20	Log-likelihood: -26.38181133686615
# Iteration: 30	Log-likelihood: -26.423169039876402
# Iteration: 40	Log-likelihood: -26.32509318097446
# Iteration: 50	Log-likelihood: -26.296349225208285
# Iteration: 60	Log-likelihood: -26.282413128959163
# Iteration: 70	Log-likelihood: -26.267864246745074
# Iteration: 80	Log-likelihood: -26.253939075714666
# Iteration: 90	Log-likelihood: -26.238610437695986

# %%
for k in range(mdl.k):
    print('Top 10 words of topic #{}'.format(k))
    print(mdl.get_topic_words(k, top_n=10))
# Out:
# Top 10 words of topic #0
# [('book', 0.051972396671772), ('thing', 0.033494580537080765), ('like', 0.030821984633803368), ('time', 0.023542486131191254), ('going', 0.02327965758740902), ('story', 0.021723350510001183), ('point', 0.015374092385172844), ('read', 0.015312076546251774), ('think', 0.014691916294395924), ('thought', 0.014479289762675762)]
# Top 10 words of topic #1
# [('life', 0.05426661670207977), ('year', 0.034966275095939636), ('school', 0.01582075096666813), ('chapter', 0.015098278410732746), ('time', 0.013903986662626266), ('later', 0.012746556662023067), ('family', 0.012259992770850658), ('long', 0.012215759605169296), ('child', 0.010991979390382767), ('making', 0.010534904897212982)]
# Top 10 words of topic #2
# [('story', 0.044585395604372025), ('book', 0.034158919006586075), ('plot', 0.033686522394418716), ('felt', 0.02964865230023861), ('character', 0.028287699446082115), ('author', 0.019289659336209297), ('time', 0.01887349970638752), ('read', 0.01580291986465454), ('reader', 0.0147681450471282), ('interesting', 0.014160776510834694)]
# Top 10 words of topic #3
# [('alive', 0.04039570316672325), ('possible', 0.03101326711475849), ('protagonist', 0.023083342239260674), ('small', 0.023044085130095482), ('town', 0.022043030709028244), ('villain', 0.01890246570110321), ('trigger', 0.01664518564939499), ('build', 0.015683388337492943), ('secret', 0.015428217127919197), ('lucy', 0.013524250127375126)]
# Top 10 words of topic #4
# [('truth', 0.042985573410987854), ('surprised', 0.024332627654075623), ('witch', 0.02307981811463833), ('adrian', 0.02252301387488842), ('deserve', 0.020351476967334747), ('juliette', 0.019015146419405937), ('warner', 0.01876458339393139), ('kissed', 0.018681064248085022), ('beast', 0.016091924160718918), ('holding', 0.015507278963923454)]
# Top 10 words of topic #5
# [('slightly', 0.02854061685502529), ('agree', 0.02648208849132061), ('sarah', 0.02533070743083954), ('cheated', 0.02079496905207634), ('violet', 0.017410609871149063), ('captured', 0.01639879122376442), ('focus', 0.014305372722446918), ('attracted', 0.013572677038609982), ('shift', 0.012491077184677124), ('generally', 0.012107283808290958)]
# Top 10 words of topic #6
# [('vampire', 0.08112873136997223), ('creepy', 0.04308360442519188), ('result', 0.028710179030895233), ('christian', 0.02845086343586445), ('unexpected', 0.025079777464270592), ('murderer', 0.024042518809437752), ('guilt', 0.023783205077052116), ('club', 0.022597767412662506), ('dynamic', 0.01655944623053074), ('carry', 0.01618899777531624)]
# Top 10 words of topic #7
# [('realistic', 0.0522724874317646), ('conflict', 0.03908195719122887), ('self', 0.037815991789102554), ('year', 0.0278924647718668), ('badly', 0.022501906380057335), ('badass', 0.020337514579296112), ('julie', 0.018744850531220436), ('thousand', 0.016008732840418816), ('lila', 0.01572287082672119), ('loses', 0.01555951964110136)]
# Top 10 words of topic #8
# [('trust', 0.075131356716156), ('enemy', 0.0418977364897728), ('understanding', 0.03126297891139984), ('emily', 0.028833486139774323), ('rich', 0.02754998207092285), ('business', 0.02672487124800682), ('wished', 0.025716403499245644), ('send', 0.024707933887839317), ('forgotten', 0.01939055509865284), ('current', 0.016915224492549896)]
# Top 10 words of topic #9
# [('step', 0.049245819449424744), ('bond', 0.03840067237615585), ('ring', 0.03239627555012703), ('class', 0.031884271651506424), ('worth', 0.02727624773979187), ('rooting', 0.021597672253847122), ('josh', 0.018525656312704086), ('richard', 0.01759474165737629), ('touching', 0.01666382886469364), ('gold', 0.015779459848999977)]
# Top 10 words of topic #10
# [('rushed', 0.04287393391132355), ('magnus', 0.04282265156507492), ('common', 0.027950292453169823), ('alec', 0.023180879652500153), ('worthy', 0.018873024731874466), ('defeat', 0.018514037132263184), ('manner', 0.015385712496936321), ('gene', 0.013744625262916088), ('serve', 0.013283069245517254), ('weakness', 0.012616376392543316)]
# Top 10 words of topic #11
# [('jace', 0.05211120471358299), ('hour', 0.04139207676053047), ('clary', 0.04046401381492615), ('ethan', 0.03763342276215553), ('sebastian', 0.024733344092965126), ('scary', 0.023480460047721863), ('hazel', 0.02069627121090889), ('shade', 0.017540857195854187), ('tired', 0.016195164993405342), ('valentine', 0.015963148325681686)]
# Top 10 words of topic #12
# [('damn', 0.06232025474309921), ('special', 0.05267104506492615), ('separation', 0.036855749785900116), ('slowly', 0.03605557233095169), ('uncle', 0.03148984909057617), ('scarlet', 0.02744188718497753), ('cinder', 0.025276698172092438), ('skill', 0.024099964648485184), ('surprising', 0.023723410442471504), ('charge', 0.019251825287938118)]
# Top 10 words of topic #13
# [('expected', 0.07165496051311493), ('showing', 0.0344192311167717), ('opportunity', 0.030475419014692307), ('social', 0.02909252420067787), ('paul', 0.027351101860404015), ('motivation', 0.02514871396124363), ('option', 0.02140977419912815), ('machine', 0.019156169146299362), ('commit', 0.01633916050195694), ('million', 0.015314793214201927)]
# Top 10 words of topic #14
# [('charlie', 0.03501316159963608), ('adorable', 0.03134295716881752), ('painful', 0.028371840715408325), ('military', 0.02161400578916073), ('elder', 0.019167201593518257), ('roth', 0.01875940151512623), ('whore', 0.01870114542543888), ('comfort', 0.018409859389066696), ('veronica', 0.01683691516518593), ('beautifully', 0.01683691516518593)]
# Top 10 words of topic #15
# [('werewolf', 0.033737797290086746), ('tough', 0.02588118426501751), ('positive', 0.025303492322564125), ('clara', 0.02513018436729908), ('mercy', 0.024205876514315605), ('introduction', 0.0206819549202919), ('tucker', 0.018024571239948273), ('laughing', 0.01744687929749489), ('maya', 0.01634926348924637), ('finishing', 0.016175957396626472)]
# Top 10 words of topic #16
# [('accidentally', 0.023928934708237648), ('mara', 0.02276914194226265), ('scientist', 0.022708101198077202), ('addressed', 0.022708101198077202), ('wearing', 0.02118206024169922), ('exception', 0.021121017634868622), ('disliked', 0.02026643604040146), ('suit', 0.017458520829677582), ('julia', 0.016298728063702583), ('cress', 0.016054561361670494)]
# Top 10 words of topic #17
# [('lovely', 0.026087608188390732), ('dealt', 0.024723220616579056), ('voldemort', 0.02461407147347927), ('goal', 0.023795438930392265), ('harry', 0.02368628792464733), ('search', 0.022485628724098206), ('dumbledore', 0.020684638991951942), ('nate', 0.01626402884721756), ('hurting', 0.015991151332855225), ('faith', 0.015445396304130554)]
# Top 10 words of topic #18
# [('hermione', 0.032268453389406204), ('everybody', 0.03105681575834751), ('regret', 0.02353191189467907), ('harry', 0.019067984074354172), ('discovery', 0.018238969147205353), ('holly', 0.01811142824590206), ('clone', 0.015943234786391258), ('location', 0.013838810846209526), ('ginny', 0.012180780991911888), ('heat', 0.010905373841524124)]
# Top 10 words of topic #19
# [('cause', 0.10247737169265747), ('drama', 0.09410861134529114), ('bother', 0.04826939478516579), ('sigh', 0.03369155153632164), ('thanks', 0.028562312945723534), ('refuse', 0.028454327955842018), ('smile', 0.023487063124775887), ('wrapped', 0.020679479464888573), ('pleased', 0.017709918320178986), ('virginity', 0.016198143362998962)]
# Top 10 words of topic #20
# [('michael', 0.03611468896269798), ('cheesy', 0.019936613738536835), ('elia', 0.01929968036711216), ('piper', 0.017962124198675156), ('coincidence', 0.016178712248802185), ('photo', 0.01579655334353447), ('laia', 0.015350701287388802), ('harsh', 0.015159621834754944), ('rate', 0.015095928683876991), ('crown', 0.014331609942018986)]
# Top 10 words of topic #21
# [('alex', 0.10695265978574753), ('lena', 0.04166662320494652), ('solution', 0.026766173541545868), ('andrew', 0.020916366949677467), ('wizard', 0.018157025799155235), ('factor', 0.017660344019532204), ('poison', 0.0159495510160923), ('talent', 0.014183572493493557), ('liar', 0.013907636515796185), ('fashion', 0.012141657993197441)]
# Top 10 words of topic #22
# [('curious', 0.04032156988978386), ('chemistry', 0.025886422023177147), ('self', 0.025886422023177147), ('card', 0.021622877568006516), ('trusted', 0.020161090418696404), ('shake', 0.015044834464788437), ('immature', 0.013643954880535603), ('biological', 0.013400323688983917), ('continuing', 0.01333941612392664), ('angle', 0.012913061305880547)]
# Top 10 words of topic #23
# [('noah', 0.05684833973646164), ('nora', 0.03029954992234707), ('quinn', 0.02178727090358734), ('riley', 0.021668218076229095), ('victor', 0.019227633252739906), ('trap', 0.01684657670557499), ('patch', 0.014167886227369308), ('spread', 0.014108359813690186), ('sean', 0.014048833400011063), ('officer', 0.013810726813971996)]
# Top 10 words of topic #24
# [('happiness', 0.037163376808166504), ('paper', 0.02310972660779953), ('condom', 0.021580876782536507), ('gwen', 0.020934056490659714), ('kidding', 0.01887599192559719), ('incest', 0.017758755013346672), ('rising', 0.011643359437584877), ('kelsier', 0.011584557592868805), ('trans', 0.010408519767224789), ('jennifer', 0.010232114233076572)]
# Top 10 words of topic #25
# [('cliffhanger', 0.043615978211164474), ('master', 0.033088114112615585), ('post', 0.030671002343297005), ('breath', 0.020680272951722145), ('divergent', 0.020089423283934593), ('jill', 0.01777973771095276), ('absolute', 0.01777973771095276), ('lame', 0.017726024612784386), ('ahead', 0.017296316102147102), ('quiet', 0.016651753336191177)]
# Top 10 words of topic #26
# [('peter', 0.058079011738300323), ('surprised', 0.056707076728343964), ('percy', 0.03313015401363373), ('jean', 0.029573289677500725), ('exciting', 0.02332337200641632), ('sexy', 0.022154686972498894), ('assumed', 0.020935190841555595), ('lara', 0.020223818719387054), ('initial', 0.01651451736688614), ('scarlett', 0.014278775081038475)]
# Top 10 words of topic #27
# [('daniel', 0.04097984358668327), ('highly', 0.026429643854498863), ('lucas', 0.024610867723822594), ('redemption', 0.020859645679593086), ('recommend', 0.020007094368338585), ('judge', 0.01909770630300045), ('anyways', 0.01892719604074955), ('aaron', 0.0142097482457757), ('william', 0.014096074737608433), ('terrified', 0.013414033688604832)]
# Top 10 words of topic #28
# [('america', 0.05441170558333397), ('princess', 0.0437193289399147), ('prince', 0.0413210391998291), ('maxon', 0.028180407360196114), ('preferred', 0.02158511057496071), ('aspen', 0.01933671347796917), ('travis', 0.018537282943725586), ('include', 0.01763792522251606), ('ally', 0.01713828183710575), ('cinder', 0.016688602045178413)]
# Top 10 words of topic #29
# [('away', 0.28508618474006653), ('pull', 0.04573088884353638), ('push', 0.04382545128464699), ('mile', 0.029230616986751556), ('sent', 0.019135857000947), ('descriptive', 0.016257431358098984), ('pushing', 0.015365524217486382), ('walk', 0.01313575729727745), ('rand', 0.012203309684991837), ('damage', 0.011676274240016937)]
# Top 10 words of topic #30
# [('necessary', 0.045764416456222534), ('animal', 0.04541083052754402), ('weak', 0.041824474930763245), ('jane', 0.03904631361365318), ('june', 0.02914595417678356), ('utterly', 0.02116505056619644), ('abby', 0.01555821392685175), ('dani', 0.014547973871231079), ('imagined', 0.013537732884287834), ('handsome', 0.011971858330070972)]
# Top 10 words of topic #31
# [('disappointing', 0.03233090788125992), ('insane', 0.025965075939893723), ('joke', 0.0241104643791914), ('disease', 0.022556599229574203), ('stage', 0.021102983504533768), ('harder', 0.0204012393951416), ('lucien', 0.019649367779493332), ('dear', 0.018947623670101166), ('strike', 0.018095504492521286), ('anne', 0.017042886465787888)]
# Top 10 words of topic #32
# [('mouth', 0.03374287113547325), ('taste', 0.02373937889933586), ('cast', 0.022858241572976112), ('dick', 0.021717946976423264), ('zero', 0.020992305129766464), ('gross', 0.020318495109677315), ('edward', 0.019644685089588165), ('detective', 0.018711715936660767), ('cheap', 0.018193401396274567), ('serum', 0.01503167487680912)]
# Top 10 words of topic #33
# [('sydney', 0.03688894957304001), ('room', 0.03131748363375664), ('share', 0.028307093307375908), ('caleb', 0.026689570397138596), ('window', 0.019320856779813766), ('plain', 0.01878168247640133), ('concerned', 0.01869182102382183), ('throwing', 0.018601957708597183), ('heal', 0.01743374764919281), ('ella', 0.016804710030555725)]
# Top 10 words of topic #34
# [('alina', 0.03264344856142998), ('murdered', 0.029495572671294212), ('jealous', 0.0263045784085989), ('guilty', 0.023372313007712364), ('ball', 0.02285485528409481), ('albus', 0.02263924665749073), ('darkling', 0.022509882226586342), ('scorpius', 0.02022443898022175), ('roll', 0.019017037004232407), ('explains', 0.016386620700359344)]
# Top 10 words of topic #35
# [('cover', 0.03603096306324005), ('virgin', 0.02974238619208336), ('moral', 0.02567027509212494), ('loose', 0.024793999269604683), ('anti', 0.02407235838472843), ('rick', 0.019690973684191704), ('juliet', 0.018093056976795197), ('medical', 0.01675286889076233), ('crash', 0.016392048448324203), ('parker', 0.013866310007870197)]
# Top 10 words of topic #36
# [('celaena', 0.03927062824368477), ('original', 0.03740239515900612), ('james', 0.034525316208601), ('aelin', 0.03426376357674599), ('chaol', 0.03295600041747093), ('dorian', 0.031610872596502304), ('deserved', 0.030639391392469406), ('curse', 0.023166460916399956), ('heck', 0.022942272946238518), ('rowan', 0.022419167682528496)]
# Top 10 words of topic #37
# [('confused', 0.056573159992694855), ('shock', 0.03553676977753639), ('nope', 0.033879633992910385), ('torture', 0.027573322877287865), ('pure', 0.021773355081677437), ('messed', 0.021589228883385658), ('forgot', 0.021359071135520935), ('value', 0.019794000312685966), ('remembered', 0.016249576583504677), ('dante', 0.015651166439056396)]
# Top 10 words of topic #38
# [('bone', 0.027902331203222275), ('mare', 0.02785567194223404), ('gabriel', 0.026829183101654053), ('deep', 0.02491617761552334), ('jail', 0.019037190824747086), ('maven', 0.018617263063788414), ('gideon', 0.018383968621492386), ('suspicion', 0.01581774465739727), ('nathan', 0.015304499305784702), ('grant', 0.01483791321516037)]
# Top 10 words of topic #39
# [('lack', 0.04618055745959282), ('miss', 0.04220603406429291), ('wonderful', 0.03016890585422516), ('mary', 0.02797345444560051), ('jump', 0.027670634910464287), ('stuck', 0.02653505653142929), ('sibling', 0.02085716463625431), ('bigger', 0.020705753937363625), ('betrayed', 0.019078092649579048), ('evie', 0.017791103571653366)]
# Top 10 words of topic #40
# [('spoiler', 0.14023980498313904), ('mark', 0.0432356595993042), ('anymore', 0.04136384278535843), ('circle', 0.016369586810469627), ('finished', 0.016186075285077095), ('continued', 0.01592915877699852), ('suspicious', 0.014461067505180836), ('easier', 0.01394723542034626), ('forth', 0.013286594301462173), ('alert', 0.012295632623136044)]
# Top 10 words of topic #41
# [('angel', 0.054452959448099136), ('particularly', 0.04647190123796463), ('letter', 0.044585466384887695), ('perspective', 0.035951413214206696), ('wrote', 0.024052375927567482), ('tied', 0.01930001750588417), ('backstory', 0.01654292456805706), ('reach', 0.016071315854787827), ('separate', 0.014547659084200859), ('fucked', 0.01447510439902544)]
# Top 10 words of topic #42
# [('romance', 0.13545992970466614), ('question', 0.06939081847667694), ('stand', 0.04998362064361572), ('sake', 0.02341269701719284), ('frustrating', 0.02051464281976223), ('cruel', 0.020091330632567406), ('safety', 0.018267836421728134), ('chase', 0.01670484058558941), ('clean', 0.01322066318243742), ('prove', 0.01322066318243742)]
# Top 10 words of topic #43
# [('yeah', 0.07392482459545135), ('upset', 0.043321847915649414), ('thomas', 0.030962955206632614), ('version', 0.025175852701067924), ('treat', 0.018080933019518852), ('hannah', 0.017459718510508537), ('attraction', 0.015007556416094303), ('zane', 0.014549819752573967), ('freak', 0.013568954542279243), ('horse', 0.01340547762811184)]
# Top 10 words of topic #44
# [('page', 0.07658567279577255), ('word', 0.07251033931970596), ('lord', 0.03014230728149414), ('wrong', 0.029988521710038185), ('interested', 0.029040174558758736), ('drug', 0.026759015396237373), ('learning', 0.018428942188620567), ('consequence', 0.01819826290011406), ('check', 0.01619904488325119), ('camp', 0.01568642631173134)]
# Top 10 words of topic #45
# [('jack', 0.050308708101511), ('choose', 0.03358062356710434), ('difference', 0.024859674274921417), ('finish', 0.02336997352540493), ('appreciate', 0.02156992070376873), ('putting', 0.021135425195097923), ('training', 0.01831120252609253), ('kick', 0.01700771600008011), ('appears', 0.016169758513569832), ('trick', 0.013904173858463764)]
# Top 10 words of topic #46
# [('tris', 0.04656669870018959), ('brought', 0.03957149386405945), ('answer', 0.038517821580171585), ('awful', 0.030146991834044456), ('heartbreaking', 0.021454205736517906), ('speak', 0.01893710345029831), ('humanity', 0.01852734200656414), ('wake', 0.017971238121390343), ('tobias', 0.017620014026761055), ('sign', 0.017561476677656174)]
# Top 10 words of topic #47
# [('love', 0.4467838704586029), ('beautiful', 0.0322829931974411), ('triangle', 0.031370654702186584), ('suicide', 0.026089606806635857), ('cute', 0.024440374225378036), ('emma', 0.021405087783932686), ('horrible', 0.018282076343894005), ('imagine', 0.016667935997247696), ('sequel', 0.014369538985192776), ('henry', 0.012878213077783585)]
# Top 10 words of topic #48
# [('wait', 0.061314187943935394), ('cheating', 0.04981318861246109), ('fucking', 0.047710854560136795), ('pregnant', 0.04343198612332344), ('history', 0.03081798553466797), ('anna', 0.030471717938780785), ('party', 0.022853851318359375), ('allowed', 0.019613783806562424), ('connection', 0.016373716294765472), ('dumb', 0.01538438256829977)]
# Top 10 words of topic #49
# [('ship', 0.04090005159378052), ('cool', 0.03973085433244705), ('game', 0.03714979812502861), ('awesome', 0.03456873819231987), ('plus', 0.03077436424791813), ('simon', 0.02784034237265587), ('hold', 0.025082802399992943), ('survive', 0.02210466004908085), ('struggle', 0.021420789882540703), ('city', 0.02137666940689087)]
# Top 10 words of topic #50
# [('guess', 0.040416400879621506), ('rose', 0.03368036821484566), ('annoying', 0.030618533492088318), ('inside', 0.026985159143805504), ('piece', 0.0255154799669981), ('shot', 0.024025388062000275), ('meeting', 0.02055530995130539), ('happening', 0.01973882131278515), ('missed', 0.01939181424677372), ('pissed', 0.019167279824614525)]
# Top 10 words of topic #51
# [('seriously', 0.07044483721256256), ('literally', 0.045906271785497665), ('nick', 0.03177478164434433), ('type', 0.02504955604672432), ('aspect', 0.023751331493258476), ('sick', 0.023091576993465424), ('hospital', 0.017494315281510353), ('excuse', 0.01747303456068039), ('respect', 0.01698353886604309), ('scared', 0.01640891470015049)]
# Top 10 words of topic #52
# [('gave', 0.03351777791976929), ('hated', 0.03251952677965164), ('absolutely', 0.031588949263095856), ('mention', 0.030759893357753754), ('fuck', 0.028137363493442535), ('shit', 0.02773129567503929), ('adam', 0.0234844908118248), ('feyre', 0.02246931754052639), ('epilogue', 0.022063249722123146), ('sudden', 0.018493225798010826)]
# Top 10 words of topic #53
# [('died', 0.07948155701160431), ('happens', 0.050149329006671906), ('remember', 0.03642580658197403), ('female', 0.026680348441004753), ('harry', 0.024188067764043808), ('money', 0.022031284868717194), ('control', 0.021983357146382332), ('tear', 0.01971474289894104), ('male', 0.019091671332716942), ('bothered', 0.018772149458527565)]
# Top 10 words of topic #54
# [('course', 0.06447936594486237), ('baby', 0.04730362072587013), ('wish', 0.045998599380254745), ('plan', 0.02576376684010029), ('kate', 0.02114708349108696), ('black', 0.021048855036497116), ('white', 0.01726008579134941), ('explained', 0.016782982274889946), ('admit', 0.01646023616194725), ('annoyed', 0.016376040875911713)]
# Top 10 words of topic #55
# [('friend', 0.092501200735569), ('best', 0.05313879996538162), ('perfect', 0.0292814951390028), ('hell', 0.029238276183605194), ('hero', 0.02828744240105152), ('star', 0.025208033621311188), ('stuff', 0.022193456068634987), ('kiss', 0.021923331543803215), ('heroine', 0.02149113453924656), ('play', 0.020950887352228165)]
# Top 10 words of topic #56
# [('dead', 0.04090983048081398), ('woman', 0.04044092819094658), ('mother', 0.03145773336291313), ('child', 0.030207322910428047), ('sense', 0.026908548548817635), ('meet', 0.02287762425839901), ('hurt', 0.018172139301896095), ('matter', 0.01797470636665821), ('gone', 0.01755516231060028), ('rape', 0.01577826589345932)]
# Top 10 words of topic #57
# [('feeling', 0.03954647108912468), ('finally', 0.035397402942180634), ('believe', 0.03466246649622917), ('killed', 0.033807262778282166), ('turn', 0.03327944502234459), ('left', 0.0292038731276989), ('family', 0.02784089371562004), ('brother', 0.021333344280719757), ('fall', 0.019756566733121872), ('definitely', 0.01832677610218525)]
# Top 10 words of topic #58
# [('ending', 0.0589570514857769), ('wanted', 0.03381524607539177), ('world', 0.033229660242795944), ('happy', 0.031645696610212326), ('kind', 0.028808964416384697), ('felt', 0.024148276075720787), ('better', 0.022636311128735542), ('great', 0.020961150527000427), ('real', 0.018983598798513412), ('coming', 0.018398012965917587)]
# Top 10 words of topic #59
# [('character', 0.06021503359079361), ('think', 0.04409240558743477), ('story', 0.027333633974194527), ('loved', 0.02693123370409012), ('death', 0.026339469477534294), ('thought', 0.022235581651329994), ('girl', 0.021528422832489014), ('thing', 0.020513547584414482), ('relationship', 0.019824141636490822), ('going', 0.018856607377529144)]
# Top 10 words of topic #60
# [('like', 0.08125428110361099), ('book', 0.06845829635858536), ('know', 0.04122927412390709), ('want', 0.027045156806707382), ('people', 0.025930609554052353), ('time', 0.02342568337917328), ('feel', 0.022936807945370674), ('come', 0.02034442126750946), ('scene', 0.01879706233739853), ('good', 0.018669238314032555)]

# %% [markdown]
# for i in range(0, 100, 10):
#     mdl.train(10)
#     print('Iteration: {}\tLog-likelihood: {}'.format(i, mdl.ll_per_word))

# %% [markdown]
# for k in range(mdl.k):
#     print('Top 10 words of topic #{}'.format(k))
#     print(mdl.get_topic_words(k, top_n=10))

# %%
mdl.summary()
# Out:
# <Basic Info>
# | CTModel (current version: 0.12.3)
# | 545865 docs, 3328934 words
# | Total Vocabs: 71826, Used Vocabs: 71826
# | Entropy of words: 8.24717
# | Entropy of term-weighted words: 8.24717
# | Removed Vocabs: <NA>
# |
# <Training Info>
# | Iterations: 100, Burn-in steps: 0
# | Optimization Interval: 2
# | Log-likelihood per word: -26.23861
# |
# <Initial Parameters>
# | tw: TermWeight.ONE
# | min_cf: 0 (minimum collection frequency of words)
# | min_df: 0 (minimum document frequency of words)
# | rm_top: 0 (the number of top words to be removed)
# | k: 61 (the number of topics between 1 ~ 32767)
# | smoothing_alpha: [0.1] (small smoothing value for preventing topic counts to be zero, given as a single `float` in case of symmetric and as a list with length `k` of `float` in case of asymmetric.)
# | eta: 0.01 (hyperparameter of Dirichlet distribution for topic-word)
# | seed: 1189228093 (random seed)
# | trained in version 0.12.3
# |
# <Parameters>
# | prior_mean (Prior mean of Logit-normal for the per-document topic distributions)
# |  [-1.9197931  -2.9775739  -3.510862   -3.950553   -4.2261243  -4.4075665
# |   -4.539038   -4.6647935  -4.6743617  -4.730655   -4.7406526  -4.834509
# |   -4.6955647  -4.8424425  -4.8070602  -4.8350043  -4.8613257  -4.7225256
# |   -4.8271813  -4.785427   -4.7467475  -4.717955   -4.638355   -4.665325
# |   -4.4466863  -4.518409   -4.606091   -4.555156   -4.5986547  -4.2472634
# |   -4.2873244  -4.4576335  -4.30142    -4.3437247  -4.4722023  -4.240186
# |   -4.2333727  -4.162148   -4.0406375  -4.173287   -3.9977012  -4.04869
# |   -3.98589    -3.882984   -3.8680766  -3.8838573  -3.8358712  -3.5942993
# |   -3.414954   -3.4953961  -3.458859   -3.4167898  -3.1914158  -3.1767812
# |   -2.9651809  -2.7711365  -2.3764935  -2.0817535  -1.6023874  -0.8444585
# |   -0.32551488]
# | prior_cov (Prior covariance of Logit-normal for the per-document topic distributions)
# |  [[6.3511076  1.321803   1.0870394  ... 0.26699343 0.14572687 0.11619165]
# |   [1.321803   6.0975533  1.1449769  ... 0.22893481 0.14588386 0.12190004]
# |   [1.0870394  1.1449769  6.008236   ... 0.20890506 0.13140582 0.10970971]
# |   ...
# |   [0.26699343 0.22893481 0.20890506 ... 2.0204363  0.11433481 0.07457916]
# |   [0.14572687 0.14588386 0.13140582 ... 0.11433481 1.0791827  0.05456308]
# |   [0.11619165 0.12190004 0.10970971 ... 0.07457916 0.05456308 0.38501996]]
# | eta (Dirichlet prior on the per-topic word distribution)
# |  0.01
# |
# <Topics>
# | #0 (337904) : book thing like time going
# | #1 (134927) : life year school chapter time
# | #2 (88190) : story book plot felt character
# | #3 (50228) : alive possible protagonist small town
# | #4 (35201) : truth surprised witch adrian deserve
# | #5 (27943) : slightly agree sarah cheated violet
# | #6 (26276) : vampire creepy result christian unexpected
# | #7 (23769) : realistic conflict self year badly
# | #8 (21097) : trust enemy understanding emily rich
# | #9 (20766) : step bond ring class worth
# | #10 (18781) : rushed magnus common alec worthy
# | #11 (20832) : jace hour clary ethan sebastian
# | #12 (20527) : damn special separation slowly uncle
# | #13 (18806) : expected showing opportunity social paul
# | #14 (16447) : charlie adorable painful military elder
# | #15 (16592) : werewolf tough positive clara mercy
# | #16 (15664) : accidentally mara scientist addressed wearing
# | #17 (17605) : lovely dealt voldemort goal harry
# | #18 (14963) : hermione everybody regret harry discovery
# | #19 (17803) : cause drama bother sigh thanks
# | #20 (14982) : michael cheesy elia piper coincidence
# | #21 (17402) : alex lena solution andrew wizard
# | #22 (15700) : curious chemistry self card trusted
# | #23 (16081) : noah nora quinn riley victor
# | #24 (16288) : happiness paper condom gwen kidding
# | #25 (17899) : cliffhanger master post breath divergent
# | #26 (18962) : peter surprised percy jean exciting
# | #27 (16876) : daniel highly lucas redemption recommend
# | #28 (19296) : america princess prince maxon preferred
# | #29 (23948) : away pull push mile sent
# | #30 (19079) : necessary animal weak jane june
# | #31 (19232) : disappointing insane joke disease stage
# | #32 (18575) : mouth taste cast dick zero
# | #33 (21538) : sydney room share caleb window
# | #34 (22472) : alina murdered jealous guilty ball
# | #35 (18682) : cover virgin moral loose anti
# | #36 (26045) : celaena original james aelin chaol
# | #37 (21006) : confused shock nope torture pure
# | #38 (20714) : bone mare gabriel deep jail
# | #39 (25700) : lack miss wonderful mary jump
# | #40 (26528) : spoiler mark anymore circle finished
# | #41 (26847) : angel particularly letter perspective wrote
# | #42 (29992) : romance question stand sake frustrating
# | #43 (29867) : yeah upset thomas version treat
# | #44 (38297) : page word lord wrong interested
# | #45 (31503) : jack choose difference finish appreciate
# | #46 (33448) : tris brought answer awful heartbreaking
# | #47 (56278) : love beautiful triangle suicide cute
# | #48 (39713) : wait cheating fucking pregnant history
# | #49 (44612) : ship cool game awesome plus
# | #50 (48272) : guess rose annoying inside piece
# | #51 (46269) : seriously literally nick type aspect
# | #52 (58385) : gave hated absolutely mention fuck
# | #53 (61875) : died happens remember female harry
# | #54 (70545) : course baby wish plan kate
# | #55 (91832) : friend best perfect hell hero
# | #56 (120842) : dead woman mother child sense
# | #57 (148954) : feeling finally believe killed turn
# | #58 (207620) : ending wanted world happy kind
# | #59 (337254) : character think story loved death
# | #60 (445203) : like book know want people
# |

# %%
mdl.save('/content/drive/MyDrive/SpoilerData/sample_hdp_model.bin')

# %%
import tomotopy as tp
mdl = tp.CTModel.load('/content/drive/MyDrive/SpoilerData/sample_hdp_model.bin')

# %%
df_review.head()
# Out:
#                                     review_sentences  \
# 0  also high energy cosmic ray entering atmospher...
# 1  avail free december http www audible com mt el...
# 2  cheat system live choice learn daniela say lif...
# 3  http www npr org recommended reading understan...
# 4  surfer love end freya finding meaning surfing ...
#
#                             user_id   timestamp  rating  has_spoiler  \
# 0  8842281e1d1347389f2ab93d60773d4d  2017-08-30       5         True
# 1  8842281e1d1347389f2ab93d60773d4d  2017-03-22       3        False
# 2  8842281e1d1347389f2ab93d60773d4d  2017-03-20       3         True
# 3  8842281e1d1347389f2ab93d60773d4d  2016-11-09       0        False
# 4  8842281e1d1347389f2ab93d60773d4d  2016-04-25       4         True
#
#     book_id                         review_id
# 0  18245960  dfdbb7b0eb5a7e4c26d59a937e2e5feb
# 1     16981  a5d2c3628987712d0e05c4f90798eb67
# 2  28684704  2ede853b14dc4583f96cf5d120af636f
# 3  27161156  ced5675e55cd9d38a524743f5c40996e
# 4  25884323  332732725863131279a8e345b63ac33e

# %%
processed_docs2= df_review['review_sentences'].map(preprocess)
processed_docs2[:10]
# Out:
# 0    [high, energy, cosmic, entering, atmosphere, d...
# 1    [avail, free, december, http, audible, ellison...
# 2    [cheat, live, choice, learn, daniela, life, wo...
# 3    [http, recommended, reading, understand, going...
# 4    [surfer, love, freya, finding, meaning, surfin...
# 5    [light, powerless, stop, turn, usher, bullet, ...
# 6    [instance, freeing, realize, gift, star, givin...
# 7     [numerous, people, publishing, told, book, year]
# 8    [overall, great, read, main, critique, irrelev...
# 9    [course, notion, cradle, cool, sure, feasibili...
# Name: review_sentences, dtype: object

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
print(len(dictionary))
# Out:
# 0 dimension
# 1 folding
# 2 interesting
# 3 making
# 4 proton
# 5 stuff
# 6 think
# 7 answering
# 8 disillusioned
# 9 happen
# 10 message
# 71826

# %%
#del processed_docs df

# %%
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)
print (len(dictionary))
# Out:
# 53616

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
bow_corpus[4310]
# Out:
# [(1358, 1)]

# %%
bow_corpus[13004310]

# %%
bow_corpus[4314]
# Out:
# [(19, 1), (26, 1), (48, 1), (307, 2), (2573, 1), (5379, 1), (6404, 1)]

# %%
bow_doc_4310 = bow_corpus[4310]
for i in range(len(bow_doc_4310)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_4310[i][0],
                                               dictionary[bow_doc_4310[i][0]],
bow_doc_4310[i][1]))
# Out:
# Word 1358 ("awful") appears 1 time.

# %%
lst_topics=[]
lst_log=[]
for i in processed_docs2.index:
  if len(processed_docs2[i])>10:
    doc_inst = mdl.make_doc(processed_docs2[i])
    topic_dist, ll = mdl.infer(doc_inst)
  else:
    doc_inst=[]
    ll=0
  #print("Topic Distribution for Unseen Docs: ", topic_dist)
  #print("Log-likelihood of inference: ", ll)
  lst_topics.append(topic_dist)
  lst_log.append(ll)

# %%
df_review['topics']=lst_topics
df_review['log']=lst_log

# %%
df_review.to_csv('/content/drive/MyDrive/SpoilerData/intensity.csv')

# %%
lda_model = gensim.models.LdaMulticore(bow_corpus[:10000000], num_topics=10, id2word=dictionary, passes=2, workers=4)

# %%
del df

# %%
import gc
gc.collect()

# %%
for index, score in sorted(lda_model[bow_corpus[1000]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model.print_topic(index, 20)))

# %%
print(type(lda_model))

# %%
print(lda_model)

# %%
from gensim import corpora, models
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]
from pprint import pprint
for doc in corpus_tfidf:
    pprint(doc)
    break

# %%
lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, num_topics=60, id2word=dictionary, passes=2, workers=4)
for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))

# %%
unseen_document = df[0]['review_sentences	']
bow_vector = dictionary.doc2bow(preprocess(unseen_document))
for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print("Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 5)))

# %%
import joblib
from sklearn.feature_extraction.text import HashingVectorizer

print ('#----------------------------------------#')
print ('# #')
print ('# tf-idf #')
print ('# #')
print ('#----------------------------------------#\n')
def TFIDF(processed_docs):

    print (' Start tfidf:' )




    #  Read the corpus , One line of corpus is a document



    print("vectorizer started")
    #  Convert the words in the text into word frequency matrix , Matrix elements  a[i][j]  Express j Words in i Frequency of words in similar texts
    vectorizer = CountVectorizer()

    joblib.dump(vectorizer, 'vec_count.joblib')

    #  This class will count each word tfidf A weight
    transformer = TfidfTransformer()

    #  first fit_transform It's calculation tf-idf  the second fit_transform It is to turn the text into a word frequency matrix

    tfidf = transformer.fit_transform(vectorizer.fit_transform(corpus))

    #  Get all the words in the bag model
   # vec should be a HashingVectorizer instance


    #  take tf-idf Matrix extraction , Elements w[i][j] Express j Words in i Class text tf-idf The weight
    weight = tfidf.toarray()
    print (weight)

    # #  Output all words
    # result = open(docPath, 'w')
    # for j in range(len(word)):
    # result.write(word[j].encode('utf-8') + ' ')
    # result.write('\r\n\r\n')
    #
    # #  Output all weights
    # for i in range(len(weight)):
    # for j in range(len(word)):
    # result.write(str(weight[i][j]) + ' ')
    # result.write('\r\n\r\n')
    #
    # result.close()

    return weight

# %%
print ('#----------------------------------------#')
print ('# #')
print ('#  drawing  #')
print ('# #')
print ('#----------------------------------------#\n')
def Draw(silhouette_avg, sample_silhouette_values, y, k):

    import matplotlib.pyplot as plt
    import matplotlib.cm as cm
    import numpy as np

    #  Create a  subplot with 1-row 2-column
    fig, ax1 = plt.subplots(1)
    fig.set_size_inches(18, 7)

    #  first  subplot  Contour coefficient points
    #  The scope is [-1, 1]
    ax1.set_xlim([-0.2, 0.5])

    #  hinder  (k + 1) * 10  In order to show these points more clearly
    ax1.set_ylim([0, len(X) + (k + 1) * 10])

    y_lower = 10

    for i in range(k): #  Traverse these clusters respectively

        ith_cluster_silhouette_values = sample_silhouette_values[y == i]
        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.spectral(float(i)/k) #  Make a color
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0,
                          ith_cluster_silhouette_values,
                          facecolor=color,
                          edgecolor=color,
                          alpha=0.7) #  This coefficient doesn't know what to do

        #  Add the category number of clustering to the contour coefficient point
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        #  Calculate the... Of the next point  y_lower y Axis position
        y_lower = y_upper + 10

    #  Make a vertical dotted line in the picture
    ax1.axvline(x=silhouette_avg, color='red', linestyle="--")

    plt.show()

# %%
print ('#----------------------------------------#')
print ('# #')
print ('# PCA #')
print ('# #')
print ('#----------------------------------------#\n')
def PCA(weight, dimension):

    from sklearn.decomposition import PCA

    print (' Original dimension : ', len(weight[0]))
    print (' Start dimensionality reduction :')

    pca = PCA(n_components=dimension) #  initialization PCA
    X = pca.fit_transform(weight) #  Return dimension reduced data
    print (' Dimensionality reduction : ', len(X[0]))
    print (X)

    return X

# %%
print ('#----------------------------------------#')
print ('# #')
print ('# BIRCH #')
print ('# #')
print ('#----------------------------------------#\n')
def birch(X, k): #  Lattice to be clustered , Number of clusters

    from sklearn.cluster import Birch

    print (' Start clustering :')

    clusterer = Birch(n_clusters=k)

    y = clusterer.fit_predict(X)
    print (' Output clustering results :')
    print (y)

    return y

# %%
print ('#----------------------------------------#')
print ('# #')
print ('#  Profile factor  #')
print ('# #')
print ('#----------------------------------------#\n')
def Silhouette(X, y):

    from sklearn.metrics import silhouette_samples, silhouette_score

    print (' Calculate the contour coefficient :')

    silhouette_avg = silhouette_score(X, y) #  Average profile factor
    sample_silhouette_values = silhouette_samples(X, y) #  Contour coefficient of each point

    pprint(silhouette_avg)

    return silhouette_avg, sample_silhouette_values

# %%
start=time.clock()
k = 3
weight, words = TFIDF(corpus)
    # #  Output all words
    # result = open(docPath, 'w')
    # for j in range(len(word)):
    # result.write(word[j].encode('utf-8') + ' ')
    # result.write('\r\n\r\n')
    #
    # #  Output all weights
    # for i in range(len(weight)):
    # for j in range(len(word)):
    # result.write(str(weight[i][j]) + ' ')
    # result.write('\r\n\r\n')
    #
    # result.close()
X = PCA(weight, dimension=60) #  Reduce the dimension of the original weight data
# y = kmeans(X, k) # y= Class labels after clustering
y = birch(X, k)
silhouette_avg, sample_silhouette_values = Silhouette(X, y) #  Profile factor
Draw(silhouette_avg, sample_silhouette_values, y, k)


end = time.clock()

# %%
tfIdfTransformer = TfidfTransformer(use_idf=True,smooth_idf=False,)
countVectorizer = CountVectorizer()
wordCount = countVectorizer.fit_transform(processed_docs)
newTfIdf = tfIdfTransformer.fit_transform(wordCount)

# %%
df3 = pd.DataFrame(newTfIdf[0].T.todense(), index=countVectorizer.get_feature_names(), columns=["TF-IDF"])
df3 = df3.sort_values('TF-IDF', ascending=False)
print (df3.head(25))
#print(w)

# %%
ivec = InvertableHashingVectorizer(weight)
ivec.fit(corpus)  # e.g. each 10-th or 100-th document
names = ivec.get_feature_names()
